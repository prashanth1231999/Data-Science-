# %% [markdown]
# Question 1 - Load the dataset into a pandas dataframe. Name the variable as “survey”.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Survey Dataset - Technical Interview.csv")

# %%
df
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000      BJP           BJP  Fully Dissatisfied
# 1     ₹ 20,000 - ₹ 30,000     RLSP         JD(U)  Somewhat Satisfied
# 2      ₹ 5,000 - ₹ 10,000   JAP(L)           BJP  Fully Dissatisfied
# 3     ₹ 10,000 - ₹ 20,000      RJD           RJD  Fully Dissatisfied
# 4     ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...                   ...      ...           ...                 ...
# 6862    BPL/Below ₹ 5,000    JD(U)           BJP     Fully Satisfied
# 6863    BPL/Below ₹ 5,000      RJD           RJD  Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000   JAP(L)           RJD           Can’t say
# 6865  ₹ 10,000 - ₹ 20,000      BJP  Did not vote     Fully Satisfied
# 6866   ₹ 5,000 - ₹ 10,000   JAP(L)        JAP(L)     Fully Satisfied
#
#         MLA_satisfaction age gender  assembly_no category    weight
# 0     Fully Dissatisfied  26   Male          211      Gen  0.346969
# 1     Fully Dissatisfied  34   Male          189       BC  0.603419
# 2     Somewhat Satisfied  25   Male          191      Gen  0.673762
# 3     Somewhat Satisfied  36   Male          194      Gen  1.101298
# 4        Fully Satisfied  22   Male          176       BC  0.333505
# ...                  ...  ..    ...          ...      ...       ...
# 6862  Fully Dissatisfied  25   Male          166      Gen  0.036329
# 6863  Fully Dissatisfied  30   Male          169       BC  0.252780
# 6864  Fully Dissatisfied  20   Male          241      Gen  1.812926
# 6865  Somewhat Satisfied  23   Male          243      Gen  0.080137
# 6866     Fully Satisfied  33   Male          241      Gen  1.797518
#
# [6867 rows x 14 columns]

# %% [markdown]
# Question 2 - How many samples were collected on each day?

# %%
ax=sns.countplot(data=df,x="collection_date")
plt.xticks(rotation=90)
for bar in ax.containers:
    ax.bar_label(bar)

# %%
df.groupby("collection_date").count()
# Out:
#                  response_id  urban_rural  education  income  Vote_Now  \
# collection_date
# 5-24-2017               1479         1479       1479    1479      1479
# 5-25-2017                998          998        998     998       998
# 5-26-2017                598          598        598     598       598
# 5-27-2017                665          665        665     665       665
# 5-28-2017                761          761        761     761       761
# 5-29-2017                620          620        620     620       620
# 5-30-2017                582          582        582     582       582
# 5-31-2017                557          557        557     557       557
# 6-1-2017                 607          607        607     607       607
#
#                  Past_Vote  CM_satisfaction  MLA_satisfaction   age  gender  \
# collection_date
# 5-24-2017             1479             1479              1479  1479    1479
# 5-25-2017              998              998               998   998     998
# 5-26-2017              598              598               598   598     598
# 5-27-2017              665              665               665   665     665
# 5-28-2017              761              761               761   761     761
# 5-29-2017              620              620               620   620     620
# 5-30-2017              582              582               582   582     582
# 5-31-2017              557              557               557   557     557
# 6-1-2017               607              607               607   607     607
#
#                  assembly_no  category  weight
# collection_date
# 5-24-2017               1479      1479    1479
# 5-25-2017                998       998     998
# 5-26-2017                598       598     598
# 5-27-2017                665       665     665
# 5-28-2017                761       761     761
# 5-29-2017                620       620     620
# 5-30-2017                582       582     582
# 5-31-2017                557       557     557
# 6-1-2017                 607       607     607

# %% [markdown]
# Question 3 - What proportion of the total respondents were aged less than 45?

# %%
df
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000      BJP           BJP  Fully Dissatisfied
# 1     ₹ 20,000 - ₹ 30,000     RLSP         JD(U)  Somewhat Satisfied
# 2      ₹ 5,000 - ₹ 10,000   JAP(L)           BJP  Fully Dissatisfied
# 3     ₹ 10,000 - ₹ 20,000      RJD           RJD  Fully Dissatisfied
# 4     ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...                   ...      ...           ...                 ...
# 6862    BPL/Below ₹ 5,000    JD(U)           BJP     Fully Satisfied
# 6863    BPL/Below ₹ 5,000      RJD           RJD  Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000   JAP(L)           RJD           Can’t say
# 6865  ₹ 10,000 - ₹ 20,000      BJP  Did not vote     Fully Satisfied
# 6866   ₹ 5,000 - ₹ 10,000   JAP(L)        JAP(L)     Fully Satisfied
#
#         MLA_satisfaction age gender  assembly_no category    weight
# 0     Fully Dissatisfied  26   Male          211      Gen  0.346969
# 1     Fully Dissatisfied  34   Male          189       BC  0.603419
# 2     Somewhat Satisfied  25   Male          191      Gen  0.673762
# 3     Somewhat Satisfied  36   Male          194      Gen  1.101298
# 4        Fully Satisfied  22   Male          176       BC  0.333505
# ...                  ...  ..    ...          ...      ...       ...
# 6862  Fully Dissatisfied  25   Male          166      Gen  0.036329
# 6863  Fully Dissatisfied  30   Male          169       BC  0.252780
# 6864  Fully Dissatisfied  20   Male          241      Gen  1.812926
# 6865  Somewhat Satisfied  23   Male          243      Gen  0.080137
# 6866     Fully Satisfied  33   Male          241      Gen  1.797518
#
# [6867 rows x 14 columns]

# %%
total=6867

# %%
df.dtypes
# Out:
# response_id           int64
# collection_date      object
# urban_rural          object
# education            object
# income               object
# Vote_Now             object
# Past_Vote            object
# CM_satisfaction      object
# MLA_satisfaction     object
# age                  object
# gender               object
# assembly_no           int64
# category             object
# weight              float64
# dtype: object

# %%
df["age"]=df["age"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df["age"]=df["age"].astype(float)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '24ko'

# %%
df["age"].unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '24ko', '56', '50', '55', '54', '62', '60', '59',
#        '47', '61', '52', '66', '57', '67', '65', '71', '63', '64', '68',
#        '69', '99', '72', '75', '76'], dtype=object)

# %%
df.replace({"age":{"24ko":"24"}},inplace=True)

# %%
df["age"].unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '56', '50', '55', '54', '62', '60', '59', '47',
#        '61', '52', '66', '57', '67', '65', '71', '63', '64', '68', '69',
#        '99', '72', '75', '76'], dtype=object)

# %%
df.isna().sum()
# Out:
# response_id         0
# collection_date     0
# urban_rural         0
# education           0
# income              0
# Vote_Now            0
# Past_Vote           0
# CM_satisfaction     0
# MLA_satisfaction    0
# age                 0
# gender              0
# assembly_no         0
# category            0
# weight              0
# dtype: int64

# %%
df["age"]=df["age"].astype(float)

# %%
df[df["age"]<45]
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000      BJP           BJP  Fully Dissatisfied
# 1     ₹ 20,000 - ₹ 30,000     RLSP         JD(U)  Somewhat Satisfied
# 2      ₹ 5,000 - ₹ 10,000   JAP(L)           BJP  Fully Dissatisfied
# 3     ₹ 10,000 - ₹ 20,000      RJD           RJD  Fully Dissatisfied
# 4     ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...                   ...      ...           ...                 ...
# 6862    BPL/Below ₹ 5,000    JD(U)           BJP     Fully Satisfied
# 6863    BPL/Below ₹ 5,000      RJD           RJD  Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000   JAP(L)           RJD           Can’t say
# 6865  ₹ 10,000 - ₹ 20,000      BJP  Did not vote     Fully Satisfied
# 6866   ₹ 5,000 - ₹ 10,000   JAP(L)        JAP(L)     Fully Satisfied
#
#         MLA_satisfaction   age gender  assembly_no category    weight
# 0     Fully Dissatisfied  26.0   Male          211      Gen  0.346969
# 1     Fully Dissatisfied  34.0   Male          189       BC  0.603419
# 2     Somewhat Satisfied  25.0   Male          191      Gen  0.673762
# 3     Somewhat Satisfied  36.0   Male          194      Gen  1.101298
# 4        Fully Satisfied  22.0   Male          176       BC  0.333505
# ...                  ...   ...    ...          ...      ...       ...
# 6862  Fully Dissatisfied  25.0   Male          166      Gen  0.036329
# 6863  Fully Dissatisfied  30.0   Male          169       BC  0.252780
# 6864  Fully Dissatisfied  20.0   Male          241      Gen  1.812926
# 6865  Somewhat Satisfied  23.0   Male          243      Gen  0.080137
# 6866     Fully Satisfied  33.0   Male          241      Gen  1.797518
#
# [6399 rows x 14 columns]

# %%
6399/total
# Out:
# 0.9318479685452162

# %% [markdown]
# Question 4 - Create a new column in the dataframe “age_group”. This column should contain the age group the respondent belongs to. The age groups are 18-25, 25-40, 40-55 and 55+. The dataframe should look like this after the column creation.

# %%
df
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000      BJP           BJP  Fully Dissatisfied
# 1     ₹ 20,000 - ₹ 30,000     RLSP         JD(U)  Somewhat Satisfied
# 2      ₹ 5,000 - ₹ 10,000   JAP(L)           BJP  Fully Dissatisfied
# 3     ₹ 10,000 - ₹ 20,000      RJD           RJD  Fully Dissatisfied
# 4     ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...                   ...      ...           ...                 ...
# 6862    BPL/Below ₹ 5,000    JD(U)           BJP     Fully Satisfied
# 6863    BPL/Below ₹ 5,000      RJD           RJD  Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000   JAP(L)           RJD           Can’t say
# 6865  ₹ 10,000 - ₹ 20,000      BJP  Did not vote     Fully Satisfied
# 6866   ₹ 5,000 - ₹ 10,000   JAP(L)        JAP(L)     Fully Satisfied
#
#         MLA_satisfaction   age gender  assembly_no category    weight
# 0     Fully Dissatisfied  26.0   Male          211      Gen  0.346969
# 1     Fully Dissatisfied  34.0   Male          189       BC  0.603419
# 2     Somewhat Satisfied  25.0   Male          191      Gen  0.673762
# 3     Somewhat Satisfied  36.0   Male          194      Gen  1.101298
# 4        Fully Satisfied  22.0   Male          176       BC  0.333505
# ...                  ...   ...    ...          ...      ...       ...
# 6862  Fully Dissatisfied  25.0   Male          166      Gen  0.036329
# 6863  Fully Dissatisfied  30.0   Male          169       BC  0.252780
# 6864  Fully Dissatisfied  20.0   Male          241      Gen  1.812926
# 6865  Somewhat Satisfied  23.0   Male          243      Gen  0.080137
# 6866     Fully Satisfied  33.0   Male          241      Gen  1.797518
#
# [6867 rows x 14 columns]

# %%
def func(x):
    if x in range(18,25):
        return "18-25"
    elif x in range(25,40):
        return "25-40"
    elif x in range(40,55):
        return "40-55"
    elif x>=55:
        return "55+"

# %%
df["age_group"]=df["age"].apply(func)

# %%
df
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000      BJP           BJP  Fully Dissatisfied
# 1     ₹ 20,000 - ₹ 30,000     RLSP         JD(U)  Somewhat Satisfied
# 2      ₹ 5,000 - ₹ 10,000   JAP(L)           BJP  Fully Dissatisfied
# 3     ₹ 10,000 - ₹ 20,000      RJD           RJD  Fully Dissatisfied
# 4     ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...                   ...      ...           ...                 ...
# 6862    BPL/Below ₹ 5,000    JD(U)           BJP     Fully Satisfied
# 6863    BPL/Below ₹ 5,000      RJD           RJD  Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000   JAP(L)           RJD           Can’t say
# 6865  ₹ 10,000 - ₹ 20,000      BJP  Did not vote     Fully Satisfied
# 6866   ₹ 5,000 - ₹ 10,000   JAP(L)        JAP(L)     Fully Satisfied
#
#         MLA_satisfaction   age gender  assembly_no category    weight  \
# 0     Fully Dissatisfied  26.0   Male          211      Gen  0.346969
# 1     Fully Dissatisfied  34.0   Male          189       BC  0.603419
# 2     Somewhat Satisfied  25.0   Male          191      Gen  0.673762
# 3     Somewhat Satisfied  36.0   Male          194      Gen  1.101298
# 4        Fully Satisfied  22.0   Male          176       BC  0.333505
# ...                  ...   ...    ...          ...      ...       ...
# 6862  Fully Dissatisfied  25.0   Male          166      Gen  0.036329
# 6863  Fully Dissatisfied  30.0   Male          169       BC  0.252780
# 6864  Fully Dissatisfied  20.0   Male          241      Gen  1.812926
# 6865  Somewhat Satisfied  23.0   Male          243      Gen  0.080137
# 6866     Fully Satisfied  33.0   Male          241      Gen  1.797518
#
#      age_group
# 0        25-40
# 1        25-40
# 2        25-40
# 3        25-40
# 4        18-25
# ...        ...
# 6862     25-40
# 6863     25-40
# 6864     18-25
# 6865     18-25
# 6866     25-40
#
# [6867 rows x 15 columns]

# %% [markdown]
# Question 5 - How many samples were collected for each age-group? Which age-group had the most samples?

# %%
df["age_group"].unique()
# Out:
# array(['25-40', '18-25', '40-55', '55+'], dtype=object)

# %%
df["age_group"].value_counts()
# Out:
# 25-40    3844
# 18-25    2094
# 40-55     801
# 55+       128
# Name: age_group, dtype: int64

# %%
answer="25-40"

# %% [markdown]
# Question 6 - What proportion of the respondents had opted for the RJD party in both the Vote_Now and the Past_Vote questions?

# %%
df.Vote_Now.value_counts()
# Out:
# BJP           2367
# RJD           1996
# JD(U)          526
# NOTA           458
# JAP(L)         313
# Plurals        217
# INC            216
# Undecided      164
# RJJP           142
# LJP            102
# Others          87
# RLSP            82
# Left Front      79
# AIMIM           37
# VIP             28
# AAP             27
# BSP             15
# HAM             11
# Name: Vote_Now, dtype: int64

# %%
a=df.Vote_Now.value_counts()
a=pd.DataFrame(a)
a
# Out:
#             Vote_Now
# BJP             2367
# RJD             1996
# JD(U)            526
# NOTA             458
# JAP(L)           313
# Plurals          217
# INC              216
# Undecided        164
# RJJP             142
# LJP              102
# Others            87
# RLSP              82
# Left Front        79
# AIMIM             37
# VIP               28
# AAP               27
# BSP               15
# HAM               11

# %%
plt.pie(x=a["Vote_Now"],labels=a.index,rotatelabels=True,autopct='%.0f%%',radius=3)
# Out:
# ([<matplotlib.patches.Wedge at 0x26f7c5ddb10>,
#   <matplotlib.patches.Wedge at 0x26f7c5dda20>,
#   <matplotlib.patches.Wedge at 0x26f7c5de7a0>,
#   <matplotlib.patches.Wedge at 0x26f7c5dee30>,
#   <matplotlib.patches.Wedge at 0x26f7c5df4c0>,
#   <matplotlib.patches.Wedge at 0x26f7c5dfb50>,
#   <matplotlib.patches.Wedge at 0x26f7cbe0220>,
#   <matplotlib.patches.Wedge at 0x26f7cbe07f0>,
#   <matplotlib.patches.Wedge at 0x26f7cbe0e80>,
#   <matplotlib.patches.Wedge at 0x26f7cbe1510>,
#   <matplotlib.patches.Wedge at 0x26f7c5ddae0>,
#   <matplotlib.patches.Wedge at 0x26f7cbe2200>,
#   <matplotlib.patches.Wedge at 0x26f7cbe2890>,
#   <matplotlib.patches.Wedge at 0x26f7cbe2f20>,
#   <matplotlib.patches.Wedge at 0x26f7cbe35b0>,
#   <matplotlib.patches.Wedge at 0x26f7cbe3c40>,
#   <matplotlib.patches.Wedge at 0x26f7cc20310>,
#   <matplotlib.patches.Wedge at 0x26f7cc209a0>],
#  [Text(1.5469897038661022, 2.9149310208188925, 'BJP'),
#   Text(-3.2935203808854827, 0.20669663928556622, 'RJD'),
#   Text(-1.5229335093899647, -2.927571267446306, 'JD(U)'),
#   Text(-0.09736294416039193, -3.298563392918866, 'NOTA'),
#   Text(1.048143280938059, -3.1291205893388643, 'JAP(L)'),
#   Text(1.7687892567027323, -2.7859261593540126, 'Plurals'),
#   Text(2.282470160684157, -2.3833442817995136, 'INC'),
#   Text(2.660318361744802, -1.952615224298801, 'Undecided'),
#   Text(2.906751824966151, -1.562304012686376, 'RJJP'),
#   Text(3.062695135737655, -1.2287792745358743, 'LJP'),
#   Text(3.1573684924510976, -0.9597000588085248, 'Others'),
#   Text(3.2220624754494103, -0.7129610117676977, 'RLSP'),
#   Text(3.265792681173253, -0.4739178869753891, 'Left Front'),
#   Text(3.2863335456424174, -0.30001971066137867, 'AIMIM'),
#   Text(3.2938009759498508, -0.20217598975103793, 'VIP'),
#   Text(3.297844952872414, -0.11924205136590064, 'AAP'),
#   Text(3.299527237247541, -0.05585705561169938, 'BSP'),
#   Text(3.2999582135044605, -0.016606899904950397, 'HAM')],
#  [Text(0.8438125657451465, 1.5899623749921228, '34%'),
#   Text(-1.7964656623011719, 0.11274362142849065, '29%'),
#   Text(-0.8306910051217988, -1.596857054970712, '8%'),
#   Text(-0.05310706045112286, -1.7992163961375631, '7%'),
#   Text(0.571714516875305, -1.7067930487302894, '5%'),
#   Text(0.964794140019672, -1.5195960869203702, '3%'),
#   Text(1.24498372400954, -1.3000059718906434, '3%'),
#   Text(1.4510827427698916, -1.0650628496175276, '2%'),
#   Text(1.5855009954360821, -0.8521658251016595, '2%'),
#   Text(1.6705609831296298, -0.6702432406559313, '1%'),
#   Text(1.7222009958824165, -0.5234727593501044, '1%'),
#   Text(1.7574886229724054, -0.3888878246005623, '1%'),
#   Text(1.7813414624581376, -0.2585006656229395, '1%'),
#   Text(1.7925455703504092, -0.16364711490620654, '1%'),
#   Text(1.7966187141544638, -0.1102778125914752, '0%'),
#   Text(1.798824519748589, -0.06504111892685488, '0%'),
#   Text(1.7997421294077494, -0.030467484879108747, '0%'),
#   Text(1.799977207366069, -0.009058309039063852, '0%')])

# %%
df.Past_Vote.value_counts()
# Out:
# BJP             2823
# JD(U)           1374
# RJD             1047
# Did not vote     804
# INC              213
# NOTA             167
# Others           132
# LJP              125
# HAM               50
# RLSP              49
# JAP(L)            42
# Left Front        30
# BSP                9
# VIP                2
# Name: Past_Vote, dtype: int64

# %%
a=df.Past_Vote.value_counts()
a=pd.DataFrame(a)
a
# Out:
#               Past_Vote
# BJP                2823
# JD(U)              1374
# RJD                1047
# Did not vote        804
# INC                 213
# NOTA                167
# Others              132
# LJP                 125
# HAM                  50
# RLSP                 49
# JAP(L)               42
# Left Front           30
# BSP                   9
# VIP                   2

# %%
plt.pie(x=a["Past_Vote"],labels=a.index,rotatelabels=True,autopct='%.0f%%',radius=3)
# Out:
# ([<matplotlib.patches.Wedge at 0x26f7cc65270>,
#   <matplotlib.patches.Wedge at 0x26f7cc65180>,
#   <matplotlib.patches.Wedge at 0x26f7cc65e10>,
#   <matplotlib.patches.Wedge at 0x26f7cc664a0>,
#   <matplotlib.patches.Wedge at 0x26f7cc66b30>,
#   <matplotlib.patches.Wedge at 0x26f7cc671c0>,
#   <matplotlib.patches.Wedge at 0x26f7cc67850>,
#   <matplotlib.patches.Wedge at 0x26f7cc67ee0>,
#   <matplotlib.patches.Wedge at 0x26f7cc9c5b0>,
#   <matplotlib.patches.Wedge at 0x26f7cc9cc40>,
#   <matplotlib.patches.Wedge at 0x26f7cc65240>,
#   <matplotlib.patches.Wedge at 0x26f7cc9d930>,
#   <matplotlib.patches.Wedge at 0x26f7cc9dfc0>,
#   <matplotlib.patches.Wedge at 0x26f7cc9e650>],
#  [Text(0.9097484531454585, 3.172121963607239, 'BJP'),
#   Text(-3.2919191980667315, -0.23079859921518173, 'JD(U)'),
#   Text(-1.2644245607009046, -3.0481519860886737, 'RJD'),
#   Text(1.446081709226041, -2.9662851667096835, 'Did not vote'),
#   Text(2.6232268728045884, -2.002169017289964, 'INC'),
#   Text(2.930005979722973, -1.5182440379555664, 'NOTA'),
#   Text(3.1096697061462915, -1.1045154225614238, 'Others'),
#   Text(3.217765198171976, -0.7321114187289142, 'LJP'),
#   Text(3.266009111822448, -0.4724240483852894, 'HAM'),
#   Text(3.284049393526989, -0.32406724745802035, 'RLSP'),
#   Text(3.294691424943866, -0.1871053564208112, 'JAP(L)'),
#   Text(3.2990662314019477, -0.07849841287154984, 'Left Front'),
#   Text(3.2999416354968143, -0.01962657164691362, 'BSP'),
#   Text(3.2999986183471046, -0.0030197528376904505, 'VIP')],
#  [Text(0.49622642898843183, 1.7302483437857665, '41%'),
#   Text(-1.7955922898545804, -0.12589014502646273, '20%'),
#   Text(-0.6896861240186751, -1.6626283560483672, '15%'),
#   Text(0.7887718413960222, -1.6179737272961907, '12%'),
#   Text(1.4308510215297754, -1.092092191249071, '3%'),
#   Text(1.5981850798488941, -0.828133111612127, '2%'),
#   Text(1.696183476079795, -0.6024629577607765, '2%'),
#   Text(1.7551446535483504, -0.3993335011248622, '2%'),
#   Text(1.7814595155395168, -0.2576858445737942, '1%'),
#   Text(1.7912996691965393, -0.17676395315892016, '1%'),
#   Text(1.7971044136057448, -0.10205746713862426, '1%'),
#   Text(1.7994906716737893, -0.042817316111754454, '0%'),
#   Text(1.7999681648164438, -0.010705402716498336, '0%'),
#   Text(1.7999992463711476, -0.0016471379114675183, '0%')])

# %% [markdown]
# Question 7 - For each day of sample collection, determine the proportion of respondents who were fully satisfied with the performance of the CM. So if there were a total of 1000 samples on day 1 and 300 out of those said they were fully satisfied, then our answer for that day would be 0.3.

# %%
df
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000      BJP           BJP  Fully Dissatisfied
# 1     ₹ 20,000 - ₹ 30,000     RLSP         JD(U)  Somewhat Satisfied
# 2      ₹ 5,000 - ₹ 10,000   JAP(L)           BJP  Fully Dissatisfied
# 3     ₹ 10,000 - ₹ 20,000      RJD           RJD  Fully Dissatisfied
# 4     ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...                   ...      ...           ...                 ...
# 6862    BPL/Below ₹ 5,000    JD(U)           BJP     Fully Satisfied
# 6863    BPL/Below ₹ 5,000      RJD           RJD  Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000   JAP(L)           RJD           Can’t say
# 6865  ₹ 10,000 - ₹ 20,000      BJP  Did not vote     Fully Satisfied
# 6866   ₹ 5,000 - ₹ 10,000   JAP(L)        JAP(L)     Fully Satisfied
#
#         MLA_satisfaction   age gender  assembly_no category    weight  \
# 0     Fully Dissatisfied  26.0   Male          211      Gen  0.346969
# 1     Fully Dissatisfied  34.0   Male          189       BC  0.603419
# 2     Somewhat Satisfied  25.0   Male          191      Gen  0.673762
# 3     Somewhat Satisfied  36.0   Male          194      Gen  1.101298
# 4        Fully Satisfied  22.0   Male          176       BC  0.333505
# ...                  ...   ...    ...          ...      ...       ...
# 6862  Fully Dissatisfied  25.0   Male          166      Gen  0.036329
# 6863  Fully Dissatisfied  30.0   Male          169       BC  0.252780
# 6864  Fully Dissatisfied  20.0   Male          241      Gen  1.812926
# 6865  Somewhat Satisfied  23.0   Male          243      Gen  0.080137
# 6866     Fully Satisfied  33.0   Male          241      Gen  1.797518
#
#      age_group
# 0        25-40
# 1        25-40
# 2        25-40
# 3        25-40
# 4        18-25
# ...        ...
# 6862     25-40
# 6863     25-40
# 6864     18-25
# 6865     18-25
# 6866     25-40
#
# [6867 rows x 15 columns]

# %%
df.dtypes
# Out:
# response_id           int64
# collection_date      object
# urban_rural          object
# education            object
# income               object
# Vote_Now             object
# Past_Vote            object
# CM_satisfaction      object
# MLA_satisfaction     object
# age                 float64
# gender               object
# assembly_no           int64
# category             object
# weight              float64
# age_group            object
# dtype: object

# %%
df["collection_date"]=pd.to_datetime(df["collection_date"])

# %%
df
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1      2017-05-24       Rural               12th Pass
# 1               2      2017-05-24       Rural                Graduate
# 2               3      2017-05-24       Rural                Graduate
# 3               4      2017-05-24       Urban                Graduate
# 4               5      2017-05-24       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863      2017-06-01       Rural               10th Pass
# 6863         6864      2017-06-01       Rural                Graduate
# 6864         6865      2017-06-01       Urban                Graduate
# 6865         6866      2017-06-01       Rural  Professional Education
# 6866         6867      2017-06-01       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000      BJP           BJP  Fully Dissatisfied
# 1     ₹ 20,000 - ₹ 30,000     RLSP         JD(U)  Somewhat Satisfied
# 2      ₹ 5,000 - ₹ 10,000   JAP(L)           BJP  Fully Dissatisfied
# 3     ₹ 10,000 - ₹ 20,000      RJD           RJD  Fully Dissatisfied
# 4     ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...                   ...      ...           ...                 ...
# 6862    BPL/Below ₹ 5,000    JD(U)           BJP     Fully Satisfied
# 6863    BPL/Below ₹ 5,000      RJD           RJD  Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000   JAP(L)           RJD           Can’t say
# 6865  ₹ 10,000 - ₹ 20,000      BJP  Did not vote     Fully Satisfied
# 6866   ₹ 5,000 - ₹ 10,000   JAP(L)        JAP(L)     Fully Satisfied
#
#         MLA_satisfaction   age gender  assembly_no category    weight  \
# 0     Fully Dissatisfied  26.0   Male          211      Gen  0.346969
# 1     Fully Dissatisfied  34.0   Male          189       BC  0.603419
# 2     Somewhat Satisfied  25.0   Male          191      Gen  0.673762
# 3     Somewhat Satisfied  36.0   Male          194      Gen  1.101298
# 4        Fully Satisfied  22.0   Male          176       BC  0.333505
# ...                  ...   ...    ...          ...      ...       ...
# 6862  Fully Dissatisfied  25.0   Male          166      Gen  0.036329
# 6863  Fully Dissatisfied  30.0   Male          169       BC  0.252780
# 6864  Fully Dissatisfied  20.0   Male          241      Gen  1.812926
# 6865  Somewhat Satisfied  23.0   Male          243      Gen  0.080137
# 6866     Fully Satisfied  33.0   Male          241      Gen  1.797518
#
#      age_group
# 0        25-40
# 1        25-40
# 2        25-40
# 3        25-40
# 4        18-25
# ...        ...
# 6862     25-40
# 6863     25-40
# 6864     18-25
# 6865     18-25
# 6866     25-40
#
# [6867 rows x 15 columns]

# %%
df.dtypes
# Out:
# response_id                  int64
# collection_date     datetime64[ns]
# urban_rural                 object
# education                   object
# income                      object
# Vote_Now                    object
# Past_Vote                   object
# CM_satisfaction             object
# MLA_satisfaction            object
# age                        float64
# gender                      object
# assembly_no                  int64
# category                    object
# weight                     float64
# age_group                   object
# dtype: object

# %%
l=[]
for i,j in df.groupby(df.collection_date):
    d={}
    d["Day"]=i
    d["Proportion"]=len(j[j["CM_satisfaction"]=="Fully Satisfied"])/len(j)*100
    l.append(d)

pd.DataFrame(l)
# Out:
#          Day  Proportion
# 0 2017-05-24    9.871535
# 1 2017-05-25    9.519038
# 2 2017-05-26    9.866221
# 3 2017-05-27    8.120301
# 4 2017-05-28   12.089356
# 5 2017-05-29   11.774194
# 6 2017-05-30   11.168385
# 7 2017-05-31   11.131059
# 8 2017-06-01   12.355848

# %%
df["CM_satisfaction"].unique()
# Out:
# array(['Fully Dissatisfied', 'Somewhat Satisfied', 'Fully Satisfied',
#        'Somewhat Dissatisfied', 'Can’t say'], dtype=object)

# %% [markdown]
# Question 8 - In a similar fashion create a day-wise proportion of respondents that opted fully dissatisfied with their MLA. Create a line plot of the result with date on x-axis and proportions on the y-axis.

# %%
df["MLA_satisfaction"].unique()
# Out:
# array(['Fully Dissatisfied', 'Somewhat Satisfied', 'Fully Satisfied',
#        'Somewhat Dissatisfied', 'Can’t say'], dtype=object)

# %%
l=[]
for i,j in df.groupby(df.collection_date):
    d={}
    d["Day"]=i
    d["Proportion"]=len(j[j["MLA_satisfaction"]=="Fully Dissatisfied"])/len(j)*100
    l.append(d)

a=pd.DataFrame(l)
a
# Out:
#          Day  Proportion
# 0 2017-05-24   59.972955
# 1 2017-05-25   63.126253
# 2 2017-05-26   59.030100
# 3 2017-05-27   60.601504
# 4 2017-05-28   60.709593
# 5 2017-05-29   56.451613
# 6 2017-05-30   62.027491
# 7 2017-05-31   57.630162
# 8 2017-06-01   63.426689

# %%
sns.lineplot(data=a,x="Day",y="Proportion")
plt.xticks(rotation=90)
# Out:
# (array([17310., 17311., 17312., 17313., 17314., 17315., 17316., 17317.,
#         17318.]),
#  [Text(17310.0, 0, '2017-05-24'),
#   Text(17311.0, 0, '2017-05-25'),
#   Text(17312.0, 0, '2017-05-26'),
#   Text(17313.0, 0, '2017-05-27'),
#   Text(17314.0, 0, '2017-05-28'),
#   Text(17315.0, 0, '2017-05-29'),
#   Text(17316.0, 0, '2017-05-30'),
#   Text(17317.0, 0, '2017-05-31'),
#   Text(17318.0, 0, '2017-06-01')])

# %% [markdown]
# Question 9 - Create a pivot-table (or crosstab) with index as Past_Vote, Column as Vote_Now and cell values as the count of samples.

# %%
df.pivot_table(index = 'Past_Vote', columns = 'Vote_Now', values = 'response_id', aggfunc = 'count')
# Out:
# Vote_Now      AAP  AIMIM     BJP  BSP  HAM   INC  JAP(L)  JD(U)   LJP  \
# Past_Vote
# BJP           7.0    1.0  1630.0  3.0  5.0  42.0   101.0  110.0  44.0
# BSP           NaN    1.0     2.0  5.0  NaN   1.0     NaN    NaN   NaN
# Did not vote  8.0    5.0   231.0  2.0  1.0  22.0    41.0   69.0  10.0
# HAM           2.0    NaN    25.0  NaN  1.0   NaN     3.0    2.0   2.0
# INC           NaN    6.0     6.0  NaN  NaN  57.0    10.0    9.0   NaN
# JAP(L)        NaN    NaN     4.0  NaN  NaN   NaN    35.0    NaN   NaN
# JD(U)         6.0   10.0   254.0  2.0  2.0  45.0    72.0  279.0  29.0
# LJP           NaN    NaN    76.0  1.0  NaN   4.0     3.0    6.0   9.0
# Left Front    NaN    1.0     2.0  NaN  NaN   1.0     NaN    NaN   NaN
# NOTA          NaN    1.0    29.0  1.0  NaN   9.0     7.0    7.0   3.0
# Others        1.0    5.0    45.0  1.0  1.0   4.0     7.0    4.0   1.0
# RJD           3.0    7.0    46.0  NaN  1.0  31.0    31.0   39.0   4.0
# RLSP          NaN    NaN    17.0  NaN  NaN   NaN     3.0    NaN   NaN
# VIP           NaN    NaN     NaN  NaN  NaN   NaN     NaN    1.0   NaN
#
# Vote_Now      Left Front   NOTA  Others  Plurals    RJD  RJJP  RLSP  \
# Past_Vote
# BJP                 13.0  194.0    32.0     87.0  370.0  88.0  24.0
# BSP                  NaN    NaN     NaN      NaN    NaN   NaN   NaN
# Did not vote        16.0   83.0    11.0     51.0  195.0  20.0   3.0
# HAM                  NaN    4.0     NaN      NaN    6.0   4.0   NaN
# INC                  3.0    6.0     3.0      3.0  100.0   1.0   2.0
# JAP(L)               NaN    NaN     1.0      NaN    2.0   NaN   NaN
# JD(U)                9.0   90.0    18.0     43.0  435.0  13.0  25.0
# LJP                  2.0    3.0     NaN      2.0   17.0   1.0   NaN
# Left Front          18.0    1.0     1.0      NaN    4.0   NaN   1.0
# NOTA                 5.0   46.0     7.0     11.0   27.0   5.0   4.0
# Others               4.0   10.0     6.0      8.0   21.0   7.0   1.0
# RJD                  9.0   18.0     8.0     10.0  811.0   1.0  10.0
# RLSP                 NaN    3.0     NaN      2.0    8.0   2.0  12.0
# VIP                  NaN    NaN     NaN      NaN    NaN   NaN   NaN
#
# Vote_Now      Undecided   VIP
# Past_Vote
# BJP                62.0  10.0
# BSP                 NaN   NaN
# Did not vote       31.0   5.0
# HAM                 1.0   NaN
# INC                 7.0   NaN
# JAP(L)              NaN   NaN
# JD(U)              36.0   6.0
# LJP                 1.0   NaN
# Left Front          NaN   1.0
# NOTA                5.0   NaN
# Others              6.0   NaN
# RJD                14.0   4.0
# RLSP                1.0   1.0
# VIP                 NaN   1.0

# %%
df.pivot_table(index = 'Past_Vote', values = 'response_id', aggfunc = 'count')
# Out:
#               response_id
# Past_Vote
# BJP                  2823
# BSP                     9
# Did not vote          804
# HAM                    50
# INC                   213
# JAP(L)                 42
# JD(U)                1374
# LJP                   125
# Left Front             30
# NOTA                  167
# Others                132
# RJD                  1047
# RLSP                   49
# VIP                     2

# %%
df.pivot_table(index = ['Past_Vote','Vote_Now'], values = 'response_id', aggfunc = 'count')
# Out:
#                      response_id
# Past_Vote Vote_Now
# BJP       AAP                  7
#           AIMIM                1
#           BJP               1630
#           BSP                  3
#           HAM                  5
# ...                          ...
# RLSP      RLSP                12
#           Undecided            1
#           VIP                  1
# VIP       JD(U)                1
#           VIP                  1
#
# [166 rows x 1 columns]

# %% [markdown]
# Question 10 - Repeat the above question with the cell values as the sum of “weight”.

# %%
df
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1      2017-05-24       Rural               12th Pass
# 1               2      2017-05-24       Rural                Graduate
# 2               3      2017-05-24       Rural                Graduate
# 3               4      2017-05-24       Urban                Graduate
# 4               5      2017-05-24       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863      2017-06-01       Rural               10th Pass
# 6863         6864      2017-06-01       Rural                Graduate
# 6864         6865      2017-06-01       Urban                Graduate
# 6865         6866      2017-06-01       Rural  Professional Education
# 6866         6867      2017-06-01       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000      BJP           BJP  Fully Dissatisfied
# 1     ₹ 20,000 - ₹ 30,000     RLSP         JD(U)  Somewhat Satisfied
# 2      ₹ 5,000 - ₹ 10,000   JAP(L)           BJP  Fully Dissatisfied
# 3     ₹ 10,000 - ₹ 20,000      RJD           RJD  Fully Dissatisfied
# 4     ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...                   ...      ...           ...                 ...
# 6862    BPL/Below ₹ 5,000    JD(U)           BJP     Fully Satisfied
# 6863    BPL/Below ₹ 5,000      RJD           RJD  Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000   JAP(L)           RJD           Can’t say
# 6865  ₹ 10,000 - ₹ 20,000      BJP  Did not vote     Fully Satisfied
# 6866   ₹ 5,000 - ₹ 10,000   JAP(L)        JAP(L)     Fully Satisfied
#
#         MLA_satisfaction   age gender  assembly_no category    weight  \
# 0     Fully Dissatisfied  26.0   Male          211      Gen  0.346969
# 1     Fully Dissatisfied  34.0   Male          189       BC  0.603419
# 2     Somewhat Satisfied  25.0   Male          191      Gen  0.673762
# 3     Somewhat Satisfied  36.0   Male          194      Gen  1.101298
# 4        Fully Satisfied  22.0   Male          176       BC  0.333505
# ...                  ...   ...    ...          ...      ...       ...
# 6862  Fully Dissatisfied  25.0   Male          166      Gen  0.036329
# 6863  Fully Dissatisfied  30.0   Male          169       BC  0.252780
# 6864  Fully Dissatisfied  20.0   Male          241      Gen  1.812926
# 6865  Somewhat Satisfied  23.0   Male          243      Gen  0.080137
# 6866     Fully Satisfied  33.0   Male          241      Gen  1.797518
#
#      age_group
# 0        25-40
# 1        25-40
# 2        25-40
# 3        25-40
# 4        18-25
# ...        ...
# 6862     25-40
# 6863     25-40
# 6864     18-25
# 6865     18-25
# 6866     25-40
#
# [6867 rows x 15 columns]

# %%
df.pivot_table(index = 'Past_Vote', columns = 'Vote_Now', values = 'weight', aggfunc = 'sum')
# Out:
# Vote_Now            AAP      AIMIM          BJP        BSP        HAM  \
# Past_Vote
# BJP            4.807335   0.349996  1049.344112   0.452551  10.171283
# BSP                 NaN   1.654731     5.174487  32.010277        NaN
# Did not vote   8.865896   5.379527   114.203906   3.329611   2.497170
# HAM            0.312607        NaN    25.348884        NaN   1.648856
# INC                 NaN  11.105958     1.642875        NaN        NaN
# JAP(L)              NaN        NaN     6.512846        NaN        NaN
# JD(U)         12.457216  29.198610   156.243100  11.005903   2.639574
# LJP                 NaN        NaN    85.010450   2.481377        NaN
# Left Front          NaN   2.298223     0.209586        NaN        NaN
# NOTA                NaN   1.061204    12.685435   0.051485        NaN
# Others        13.661335  21.212705    34.866218   0.684568   1.505864
# RJD            5.515847  24.149369    32.285093        NaN   0.960400
# RLSP                NaN        NaN    23.376575        NaN        NaN
# VIP                 NaN        NaN          NaN        NaN        NaN
#
# Vote_Now             INC      JAP(L)       JD(U)        LJP  Left Front  \
# Past_Vote
# BJP            50.055502   63.832368   68.029581  45.716215    7.537394
# BSP             2.298223         NaN         NaN        NaN         NaN
# Did not vote   27.791290   26.359190   58.983458  11.801813   13.050113
# HAM                  NaN    0.712161    1.006719   2.496424         NaN
# INC           161.742302   18.942597   11.077323        NaN    6.268726
# JAP(L)               NaN   57.876224         NaN        NaN         NaN
# JD(U)          91.806262  106.217216  498.796862  33.148113   11.765603
# LJP            21.613385    7.375946   11.382812  26.868529    1.712452
# Left Front      2.291368         NaN         NaN        NaN   44.280864
# NOTA            3.844332    8.645440   12.132362   1.353138    2.863587
# Others          1.389539    5.333891    5.101976   2.481377    4.017150
# RJD            67.072640   28.661774   55.385673   9.226178   35.399702
# RLSP                 NaN    3.269255         NaN        NaN         NaN
# VIP                  NaN         NaN    0.333505        NaN         NaN
#
# Vote_Now            NOTA     Others    Plurals          RJD       RJJP  \
# Past_Vote
# BJP           114.913686   8.790137  50.016163   250.948101  16.047570
# BSP                  NaN        NaN        NaN          NaN        NaN
# Did not vote   44.725179   7.289933  25.319524   173.882525   4.349832
# HAM             0.928984        NaN        NaN     7.713008   1.903148
# INC             5.999014   1.552038   1.588527   195.020050   5.340403
# JAP(L)               NaN   3.195682        NaN     2.164824        NaN
# JD(U)          61.109706  29.196072  45.175289   657.155514   4.015909
# LJP             0.813171        NaN   1.927965    30.737989   0.478933
# Left Front      0.201455   8.309203        NaN     6.740281        NaN
# NOTA           35.310377  13.594657   3.676105    20.552066   1.116006
# Others          9.419087   8.236678   2.715087    38.194805   1.754671
# RJD            25.113668  14.999222  14.179660  1016.975742   0.085758
# RLSP            1.097574        NaN   0.499403    14.951502   1.955662
# VIP                  NaN        NaN        NaN          NaN        NaN
#
# Vote_Now           RLSP  Undecided        VIP
# Past_Vote
# BJP           18.715113  41.286954  18.691691
# BSP                 NaN        NaN        NaN
# Did not vote   5.041587  22.015457  10.696552
# HAM                 NaN   0.039564        NaN
# INC            1.140299   8.558475        NaN
# JAP(L)              NaN        NaN        NaN
# JD(U)         44.376194  58.137833  20.675288
# LJP                 NaN   1.709409        NaN
# Left Front     0.877960        NaN   3.020887
# NOTA           4.502676   1.570309        NaN
# Others         3.800565   2.504778        NaN
# RJD           10.752145  21.523115  13.161145
# RLSP          23.505807   3.524302   8.258391
# VIP                 NaN        NaN   0.372959

# %%
df.pivot_table(index = 'Past_Vote', values = 'weight', aggfunc = 'sum')
# Out:
#                    weight
# Past_Vote
# BJP           1819.705752
# BSP             41.137719
# Did not vote   565.582563
# HAM             42.110354
# INC            429.978586
# JAP(L)          69.749576
# JD(U)         1873.120263
# LJP            192.112418
# Left Front      68.229827
# NOTA           122.959180
# Others         156.880293
# RJD           1375.447133
# RLSP            80.438471
# VIP              0.706465

# %% [markdown]
# Question 11 - Create a dataframe by performing a group by over age_group and calculate the count of total samples under each age_group.

# %%
df
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1      2017-05-24       Rural               12th Pass
# 1               2      2017-05-24       Rural                Graduate
# 2               3      2017-05-24       Rural                Graduate
# 3               4      2017-05-24       Urban                Graduate
# 4               5      2017-05-24       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863      2017-06-01       Rural               10th Pass
# 6863         6864      2017-06-01       Rural                Graduate
# 6864         6865      2017-06-01       Urban                Graduate
# 6865         6866      2017-06-01       Rural  Professional Education
# 6866         6867      2017-06-01       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000      BJP           BJP  Fully Dissatisfied
# 1     ₹ 20,000 - ₹ 30,000     RLSP         JD(U)  Somewhat Satisfied
# 2      ₹ 5,000 - ₹ 10,000   JAP(L)           BJP  Fully Dissatisfied
# 3     ₹ 10,000 - ₹ 20,000      RJD           RJD  Fully Dissatisfied
# 4     ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...                   ...      ...           ...                 ...
# 6862    BPL/Below ₹ 5,000    JD(U)           BJP     Fully Satisfied
# 6863    BPL/Below ₹ 5,000      RJD           RJD  Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000   JAP(L)           RJD           Can’t say
# 6865  ₹ 10,000 - ₹ 20,000      BJP  Did not vote     Fully Satisfied
# 6866   ₹ 5,000 - ₹ 10,000   JAP(L)        JAP(L)     Fully Satisfied
#
#         MLA_satisfaction   age gender  assembly_no category    weight  \
# 0     Fully Dissatisfied  26.0   Male          211      Gen  0.346969
# 1     Fully Dissatisfied  34.0   Male          189       BC  0.603419
# 2     Somewhat Satisfied  25.0   Male          191      Gen  0.673762
# 3     Somewhat Satisfied  36.0   Male          194      Gen  1.101298
# 4        Fully Satisfied  22.0   Male          176       BC  0.333505
# ...                  ...   ...    ...          ...      ...       ...
# 6862  Fully Dissatisfied  25.0   Male          166      Gen  0.036329
# 6863  Fully Dissatisfied  30.0   Male          169       BC  0.252780
# 6864  Fully Dissatisfied  20.0   Male          241      Gen  1.812926
# 6865  Somewhat Satisfied  23.0   Male          243      Gen  0.080137
# 6866     Fully Satisfied  33.0   Male          241      Gen  1.797518
#
#      age_group
# 0        25-40
# 1        25-40
# 2        25-40
# 3        25-40
# 4        18-25
# ...        ...
# 6862     25-40
# 6863     25-40
# 6864     18-25
# 6865     18-25
# 6866     25-40
#
# [6867 rows x 15 columns]

# %%
df.groupby(df.age_group)["response_id"].count()
# Out:
# age_group
# 18-25    2094
# 25-40    3844
# 40-55     801
# 55+       128
# Name: response_id, dtype: int64

# %%
a1=df.groupby(df.age_group)["response_id"].count()
a1.index
# Out:
# Index(['18-25', '25-40', '40-55', '55+'], dtype='object', name='age_group')

# %%
a1=df.groupby(df.age_group)["response_id"].count()
a1=pd.DataFrame(a)
a1["age_group"]=['18-25', '25-40', '40-55', '55+']
a1.rename(columns={"response_id":"count"},inplace=True)
a1
# Out:
#    count age_group
# 0   2094     18-25
# 1   3844     25-40
# 2    801     40-55
# 3    128       55+

# %% [markdown]
# Question 12 - Create a dataframe by performing a group by over age_group and finding the count of total samples for each age_group that opted for the JD(U) party in Vote_Now.

# %%
df
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1      2017-05-24       Rural               12th Pass
# 1               2      2017-05-24       Rural                Graduate
# 2               3      2017-05-24       Rural                Graduate
# 3               4      2017-05-24       Urban                Graduate
# 4               5      2017-05-24       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863      2017-06-01       Rural               10th Pass
# 6863         6864      2017-06-01       Rural                Graduate
# 6864         6865      2017-06-01       Urban                Graduate
# 6865         6866      2017-06-01       Rural  Professional Education
# 6866         6867      2017-06-01       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000      BJP           BJP  Fully Dissatisfied
# 1     ₹ 20,000 - ₹ 30,000     RLSP         JD(U)  Somewhat Satisfied
# 2      ₹ 5,000 - ₹ 10,000   JAP(L)           BJP  Fully Dissatisfied
# 3     ₹ 10,000 - ₹ 20,000      RJD           RJD  Fully Dissatisfied
# 4     ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...                   ...      ...           ...                 ...
# 6862    BPL/Below ₹ 5,000    JD(U)           BJP     Fully Satisfied
# 6863    BPL/Below ₹ 5,000      RJD           RJD  Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000   JAP(L)           RJD           Can’t say
# 6865  ₹ 10,000 - ₹ 20,000      BJP  Did not vote     Fully Satisfied
# 6866   ₹ 5,000 - ₹ 10,000   JAP(L)        JAP(L)     Fully Satisfied
#
#         MLA_satisfaction   age gender  assembly_no category    weight  \
# 0     Fully Dissatisfied  26.0   Male          211      Gen  0.346969
# 1     Fully Dissatisfied  34.0   Male          189       BC  0.603419
# 2     Somewhat Satisfied  25.0   Male          191      Gen  0.673762
# 3     Somewhat Satisfied  36.0   Male          194      Gen  1.101298
# 4        Fully Satisfied  22.0   Male          176       BC  0.333505
# ...                  ...   ...    ...          ...      ...       ...
# 6862  Fully Dissatisfied  25.0   Male          166      Gen  0.036329
# 6863  Fully Dissatisfied  30.0   Male          169       BC  0.252780
# 6864  Fully Dissatisfied  20.0   Male          241      Gen  1.812926
# 6865  Somewhat Satisfied  23.0   Male          243      Gen  0.080137
# 6866     Fully Satisfied  33.0   Male          241      Gen  1.797518
#
#      age_group
# 0        25-40
# 1        25-40
# 2        25-40
# 3        25-40
# 4        18-25
# ...        ...
# 6862     25-40
# 6863     25-40
# 6864     18-25
# 6865     18-25
# 6866     25-40
#
# [6867 rows x 15 columns]

# %%
l=[]
for i,j in df.groupby(df.age_group):
    d={}
    d["age_group"]=i
    d["count"]=len(j[j["Vote_Now"]=="JD(U)"])
    l.append(d)
a2=pd.DataFrame(l)
a2
# Out:
#   age_group  count
# 0     18-25    181
# 1     25-40    264
# 2     40-55     68
# 3       55+     13

# %%
a1.dtypes
# Out:
# count         int64
# age_group    object
# dtype: object

# %%
a2.dtypes
# Out:
# age_group    object
# count         int64
# dtype: object

# %%
pd.merge(a1,a2,on="age_group")
# Out:
#    count_x age_group  count_y
# 0     2094     18-25      181
# 1     3844     25-40      264
# 2      801     40-55       68
# 3      128       55+       13
