# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading data

# %%
df=pd.read_csv("air_index.csv")
df
# Out:
#       Rank  Countries            City  2022    JAN    FEB    MAR    APR  \
# 0        1   Pakistan          Lahore  97.4  133.0  102.5   85.6   69.3
# 1        2      China           Hotan  94.3   61.7   91.6  132.7  106.2
# 2        3      India         Bhiwadi  92.7  110.6   98.0  116.2  149.5
# 3        4      India     Delhi (NCT)  92.6  141.0  100.9   91.0   98.0
# 4        5   Pakistan        Peshawar  91.8  110.2  103.5   78.3   68.5
# ...    ...        ...             ...   ...    ...    ...    ...    ...
# 7318  7319        USA     Castroville   0.8    0.3    0.4    0.4    0.6
# 7319  7320        USA          Wilson   0.8    0.9    0.8    0.5    0.6
# 7320  7321        USA  Roanoke Rapids   0.6    0.8    0.7    0.5    0.4
# 7321  7322  Indonesia            Kuta   0.5    2.3    0.9    0.3    0.5
# 7322  7323        USA       Arch Cape   0.2    0.2    0.1    0.1    0.1
#
#         MAY    JUN  ...   AUG   SEP    OCT    NOV    DEC   2021   2020   2019  \
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Countries', 'City', '2022', 'JAN', 'FEB', 'MAR', 'APR', 'MAY',
#        'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', '2021', '2020', '2019',
#        '2018', '2017'],
#       dtype='object')

# %% [markdown]
# ### Find top 20 good indian cities according to latest data(2022)

# %%
df.Countries.unique()
# Out:
# array(['Pakistan', 'China', 'India', 'Chad', 'Iraq', 'Kazakhstan',
#        'Bahrain', 'Bangladesh', 'Burkina Faso', 'Saudi Arabia',
#        'Tajikistan', 'Kuwait', 'United Arab Emirates', 'Montenegro',
#        'Turkey', 'Russia', 'Indonesia', 'Bosnia Herzegovina', 'Qatar',
#        'Egypt', 'Nigeria', 'Sudan', 'Rwanda', 'South Africa', 'Serbia',
#        'Peru', 'Nepal', 'Vietnam', 'Kyrgyzstan', 'Uganda', 'Chile',
#        'Croatia', 'Thailand', 'Iran', 'Mexico', 'USA', 'Uzbekistan',
#        'Ghana', 'Mongolia', 'Poland', 'Armenia', 'Ethiopia', 'Sri Lanka',
#        'South Korea', 'Romania', 'North Macedonia', 'Italy', 'Laos',
#        'Malaysia', 'Georgia', 'Kosovo', 'Israel', 'Czech Republic',
#        'Gabon', 'Zambia', 'Philippines', 'Myanmar', 'Greece',
#        'Madagascar', 'Brazil', nan, 'Moldova', 'Ivory Coast', 'Maldives',
#        'Syria', 'Turkmenistan', 'Slovakia', 'Portugal', 'Colombia',
#        'Senegal', 'Guatemala', 'Slovenia', 'Taiwan', 'Hungary',
# ...

# %%
len(df.Countries.unique())
# Out:
# 134

# %%
df[df.Countries=="India"].sort_values(by="2022").head(20)
# Out:
#       Rank Countries             City  2022   JAN   FEB   MAR   APR   MAY  \
# 7314  7315     India       Tarakeswar   0.9   2.3   2.0   1.9   1.0   1.1
# 7293  7294     India           Digboi   1.4   0.4   0.3   1.3   1.4   1.7
# 7132  7133     India            Aladu   2.7   2.0   2.0   3.5   4.0   4.6
# 7110  7111     India       Kattupalli   2.8   4.1   3.6   3.0   2.8   3.2
# 4493  4494     India       Polampalle   8.3   8.9   8.5   9.6   9.1   8.8
# 3299  3300     India        Kharsawan   9.8   9.6  11.4   6.3  12.2   3.6
# 2801  2802     India    Muttayyapuram  10.6   8.0   8.0   8.0   8.0   8.0
# 2545  2546     India       Bolai T.E.  11.1  24.4  18.0  25.1   6.2   7.9
# 1950  1951     India           Barmer  13.1  13.7  14.5  15.7  15.8  21.8
# 1700  1701     India         Ariyalur  14.5  20.3  19.0  22.8  17.1  19.2
# 1666  1667     India          Charoda  14.7  17.1  20.3  26.2  23.4  16.2
# 1560  1561     India        Singardih  15.5   8.4   6.6  17.2  19.2  14.8
# ...

# %%
df[df.Countries=="India"].sort_values(by="2022").head(20)["City"]
# Out:
# 7314         Tarakeswar
# 7293             Digboi
# 7132              Aladu
# 7110         Kattupalli
# 4493         Polampalle
# 3299          Kharsawan
# 2801      Muttayyapuram
# 2545         Bolai T.E.
# 1950             Barmer
# 1700           Ariyalur
# 1666            Charoda
# 1560          Singardih
# 1481    Tiruchirappalli
# 1406         Vijayapura
# 1318       Chamrajnagar
# 1279           Gadariya
# 1229           Balvandi
# 1230        Chikmagalur
# 1161     Ramanathapuram
# 1154             Koppal
# Name: City, dtype: object

# %% [markdown]
# ### Find top 20 good indian cities according to all year data

# %%
df.isna().sum()
# Out:
# Rank            0
# Countries       1
# City            0
# 2022            0
# JAN           224
# FEB           170
# MAR            83
# APR            45
# MAY            21
# JUN            26
# JUL            26
# AUG            33
# SEP            81
# OCT            98
# NOV           158
# DEC           267
# 2021          861
# 2020         3370
# 2019         3576
# 2018         4977
# 2017         5154
# dtype: int64

# %%
df["APR"]
# Out:
# 0        69.3
# 1       106.2
# 2       149.5
# 3        98.0
# 4        68.5
#         ...
# 7318      0.6
# 7319      0.6
# 7320      0.4
# 7321      0.5
# 7322      0.1
# Name: APR, Length: 7323, dtype: float64

# %%
s=[i for i in range(1,11)]
sum(s)/len(s)
# Out:
# 5.5

# %%
pd.Series([1,2,3,4,5,np.nan,6,7,8,9,10]).mean()  #while calculating mean null values are discarded(not counted)
# Out:
# 5.5

# %%
df
# Out:
#       Rank  Countries            City  2022    JAN    FEB    MAR    APR  \
# 0        1   Pakistan          Lahore  97.4  133.0  102.5   85.6   69.3
# 1        2      China           Hotan  94.3   61.7   91.6  132.7  106.2
# 2        3      India         Bhiwadi  92.7  110.6   98.0  116.2  149.5
# 3        4      India     Delhi (NCT)  92.6  141.0  100.9   91.0   98.0
# 4        5   Pakistan        Peshawar  91.8  110.2  103.5   78.3   68.5
# ...    ...        ...             ...   ...    ...    ...    ...    ...
# 7318  7319        USA     Castroville   0.8    0.3    0.4    0.4    0.6
# 7319  7320        USA          Wilson   0.8    0.9    0.8    0.5    0.6
# 7320  7321        USA  Roanoke Rapids   0.6    0.8    0.7    0.5    0.4
# 7321  7322  Indonesia            Kuta   0.5    2.3    0.9    0.3    0.5
# 7322  7323        USA       Arch Cape   0.2    0.2    0.1    0.1    0.1
#
#         MAY    JUN  ...   SEP    OCT    NOV    DEC   2021   2020   2019  \
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Countries', 'City', '2022', 'JAN', 'FEB', 'MAR', 'APR', 'MAY',
#        'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', '2021', '2020', '2019',
#        '2018', '2017'],
#       dtype='object')

# %%
df["mean"]=(df['2022']+df['JAN']+df['FEB']+df['MAR']+df['APR']+df['MAY']+df['JUN']+df['JUL']+df['AUG']+df['SEP']+df['OCT']+df['NOV']+df['DEC']+df['2021']+df['2020']+df['2019']+df['2018']+df['2017'])/18

# %%
df[df.Countries=="India"].sort_values(by="mean").head(20)
# Out:
#      Rank Countries           City  2022    JAN    FEB   MAR   APR   MAY  \
# 685   686     India        Chennai  25.3   20.1   24.9  29.5  14.5  26.0
# 433   434     India       Tirupati  31.9   32.3   39.2  50.0  30.4  36.7
# 442   443     India      Bengaluru  31.5   37.9   42.5  45.1  39.9  29.5
# 357   358     India         Nashik  34.3   44.7   33.4  37.6  36.7  30.6
# 329   330     India     Chandrapur  35.1   25.5   26.3  45.5  37.8  37.5
# 254   255     India        Solapur  39.3   40.5   45.3  47.5  41.6  42.5
# 199   200     India      Hyderabad  42.4   61.0   55.8  56.4  43.4  39.5
# 134   135     India         Nagpur  46.8   34.2   27.9  27.4  58.0  53.6
# 163   164     India  Visakhapatnam  44.7   68.7   54.3  50.9  21.7  34.6
# 137   138     India         Mumbai  46.7   74.8   65.9  67.5  41.7  41.5
# 91     92     India           Pune  51.1   73.2   61.0  67.3  62.1  65.5
# 274   275     India           Agra  38.2   87.5   42.4  49.4  42.6  37.0
# ...

# %%
df.sort_values(by="Rank")[df["Countries"]=="India"]
# Out:
#       Rank Countries         City  2022    JAN    FEB    MAR    APR    MAY  \
# 2        3     India      Bhiwadi  92.7  110.6   98.0  116.2  149.5  123.8
# 3        4     India  Delhi (NCT)  92.6  141.0  100.9   91.0   98.0   73.2
# 5        6     India    Darbhanga  90.3  127.0   77.9   83.1   64.9   46.3
# 6        7     India       Asopur  90.2  110.3   89.0  104.6  124.4   73.4
# 8        9     India    New Delhi  89.1  133.7   95.2   86.4   93.7   72.5
# ...    ...       ...          ...   ...    ...    ...    ...    ...    ...
# 4493  4494     India   Polampalle   8.3    8.9    8.5    9.6    9.1    8.8
# 7110  7111     India   Kattupalli   2.8    4.1    3.6    3.0    2.8    3.2
# 7132  7133     India        Aladu   2.7    2.0    2.0    3.5    4.0    4.6
# 7293  7294     India       Digboi   1.4    0.4    0.3    1.3    1.4    1.7
# 7314  7315     India   Tarakeswar   0.9    2.3    2.0    1.9    1.0    1.1
#
# ...
