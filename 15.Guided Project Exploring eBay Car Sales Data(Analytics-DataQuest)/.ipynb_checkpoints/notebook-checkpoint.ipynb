# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1.Reading data

# %%
pd.read_csv("autos.csv",encoding="Windows-1252")
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
df=pd.read_csv("autos.csv",encoding="Latin1")
df
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
df.head(5)
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# ...

# %%
df.dtypes
# Out:
# dateCrawled            object
# name                   object
# seller                 object
# offerType              object
# price                   int64
# abtest                 object
# vehicleType            object
# yearOfRegistration      int64
# gearbox                object
# powerPS                 int64
# model                  object
# kilometer               int64
# monthOfRegistration     int64
# fuelType               object
# brand                  object
# notRepairedDamage      object
# dateCreated            object
# nrOfPictures            int64
# postalCode              int64
# lastSeen               object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          333659 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              351319 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                351044 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             338142 non-null  object
#  14  brand                371528 non-null  object
# ...

# %%
df.describe()
# Out:
#               price  yearOfRegistration        powerPS      kilometer  \
# count  3.715280e+05       371528.000000  371528.000000  371528.000000
# mean   1.729514e+04         2004.577997     115.549477  125618.688228
# std    3.587954e+06           92.866598     192.139578   40112.337051
# min    0.000000e+00         1000.000000       0.000000    5000.000000
# 25%    1.150000e+03         1999.000000      70.000000  125000.000000
# 50%    2.950000e+03         2003.000000     105.000000  150000.000000
# 75%    7.200000e+03         2008.000000     150.000000  150000.000000
# max    2.147484e+09         9999.000000   20000.000000  150000.000000
#
#        monthOfRegistration  nrOfPictures    postalCode
# count        371528.000000      371528.0  371528.00000
# mean              5.734445           0.0   50820.66764
# std               3.712412           0.0   25799.08247
# min               0.000000           0.0    1067.00000
# 25%               3.000000           0.0   30459.00000
# ...

# %% [markdown]
# ## 2.Cleaning Column Names

# %%
df.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
df.rename(columns={"yearOfRegistration": "registration_year",
                    "monthOfRegistration": "registration_month",
                  "notRepairedDamage":"unrepaired_damage",
                  "dateCreated":"ad_created"},inplace=True)
df
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  registration_year  \
# ...

# %% [markdown]
# ## 3.Initial Exploration and Cleaning.

# %%
df.dtypes
# Out:
# dateCrawled           object
# name                  object
# seller                object
# offerType             object
# price                  int64
# abtest                object
# vehicleType           object
# registration_year      int64
# gearbox               object
# powerPS                int64
# model                 object
# kilometer              int64
# registration_month     int64
# fuelType              object
# brand                 object
# unrepaired_damage     object
# ad_created            object
# nrOfPictures           int64
# postalCode             int64
# lastSeen              object
# dtype: object

# %%
df.rename(columns={"kilometer":"odometer_km"},inplace=True)
df
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  registration_year  \
# ...

# %%
df["seller"].unique()
# Out:
# array(['privat', 'gewerblich'], dtype=object)

# %%
df["seller"].value_counts() #mostly all values are privat
# Out:
# seller
# privat        371525
# gewerblich         3
# Name: count, dtype: int64

# %%
df["offerType"].unique()
# Out:
# array(['Angebot', 'Gesuch'], dtype=object)

# %%
df["offerType"].value_counts() #mostly all values are angebot
# Out:
# offerType
# Angebot    371516
# Gesuch         12
# Name: count, dtype: int64

# %%
df["vehicleType"].value_counts()
# Out:
# vehicleType
# limousine     95894
# kleinwagen    80023
# kombi         67564
# bus           30201
# cabrio        22898
# coupe         19015
# suv           14707
# andere         3357
# Name: count, dtype: int64

# %%
df[["price","odometer_km"]].describe()
# Out:
#               price    odometer_km
# count  3.715280e+05  371528.000000
# mean   1.729514e+04  125618.688228
# std    3.587954e+06   40112.337051
# min    0.000000e+00    5000.000000
# 25%    1.150000e+03  125000.000000
# 50%    2.950000e+03  150000.000000
# 75%    7.200000e+03  150000.000000
# max    2.147484e+09  150000.000000

# %% [markdown]
# ## 4.Exploring the date columns

# %%
df[["dateCrawled","registration_year","registration_month","ad_created","lastSeen"]].isna().sum()
# Out:
# dateCrawled           0
# registration_year     0
# registration_month    0
# ad_created            0
# lastSeen              0
# dtype: int64

# %%
df["registration_year"].value_counts(normalize=True,dropna=False)
# Out:
# registration_year
# 2000    0.066081
# 1999    0.061279
# 2005    0.060065
# 2006    0.054451
# 2001    0.054419
#           ...
# 2066    0.000003
# 9450    0.000003
# 3200    0.000003
# 1925    0.000003
# 3500    0.000003
# Name: proportion, Length: 155, dtype: float64

# %%
df["registration_year"].value_counts(normalize=True,dropna=False).sort_index(ascending=False)
# Out:
# registration_year
# 9999    0.000073
# 9996    0.000003
# 9450    0.000003
# 9229    0.000003
# 9000    0.000013
#           ...
# 1200    0.000003
# 1111    0.000011
# 1039    0.000003
# 1001    0.000003
# 1000    0.000102
# Name: proportion, Length: 155, dtype: float64

# %% [markdown]
# ## 5.Dealing with Incorrect Registration Year Data

# %%
df["registration_year"].describe()
# Out:
# count    371528.000000
# mean       2004.577997
# std          92.866598
# min        1000.000000
# 25%        1999.000000
# 50%        2003.000000
# 75%        2008.000000
# max        9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# Because a car can't be first registered after the listing was seen, any vehicle with a registration year above 2016 is definitely inaccurate. Determining the earliest valid year is more difficult. Realistically, it could be somewhere in the first few decades of the 1900s.
#
# Let's count the number of listings with cars that fall outside the 1900 - 2016 interval and see if it's safe to remove those rows entirely, or if we need more custom logic.

# %%
new_df=df[df["registration_year"].between(1900,2016,inclusive="both")]
new_df
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  registration_year  \
# ...

# %%
new_df["registration_year"].value_counts(normalize=True)
# Out:
# registration_year
# 2000    0.068813
# 1999    0.063812
# 2005    0.062548
# 2006    0.056702
# 2001    0.056668
#           ...
# 1911    0.000003
# 1919    0.000003
# 1915    0.000003
# 1920    0.000003
# 1925    0.000003
# Name: proportion, Length: 97, dtype: float64

# %% [markdown]
# ## 6.Exploring Price by Brand

# %%
new_df["brand"].unique()
# Out:
# array(['volkswagen', 'audi', 'jeep', 'skoda', 'bmw', 'peugeot', 'ford',
#        'mazda', 'nissan', 'renault', 'mercedes_benz', 'seat', 'honda',
#        'fiat', 'opel', 'mini', 'smart', 'hyundai', 'sonstige_autos',
#        'alfa_romeo', 'subaru', 'volvo', 'mitsubishi', 'kia', 'suzuki',
#        'lancia', 'porsche', 'citroen', 'toyota', 'chevrolet', 'dacia',
#        'daihatsu', 'trabant', 'saab', 'chrysler', 'jaguar', 'daewoo',
#        'rover', 'land_rover', 'lada'], dtype=object)

# %%
a=new_df["brand"].value_counts(normalize=True).reset_index()
a[a["proportion"]>0.05]
# Out:
#            brand  proportion
# 0     volkswagen    0.212391
# 1            bmw    0.109695
# 2           opel    0.107069
# 3  mercedes_benz    0.095955
# 4           audi    0.089352
# 5           ford    0.068849

# %%
a[a["proportion"]>0.05]["brand"].values
# Out:
# array(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'],
#       dtype=object)

# %%
b=new_df.groupby(new_df.brand)["price"].mean().reset_index()
b
# Out:
#              brand          price
# 0       alfa_romeo   36896.854305
# 1             audi   16218.259230
# 2              bmw   14798.226103
# 3        chevrolet    7485.864170
# 4         chrysler    3925.278094
# 5          citroen    9167.919798
# 6            dacia    5861.871854
# 7           daewoo    1011.812865
# 8         daihatsu    1704.548718
# 9             fiat    4146.933841
# 10            ford    8702.476063
# 11           honda    3863.605098
# 12         hyundai    5487.679498
# 13          jaguar   14232.819218
# 14            jeep   12207.964103
# 15             kia    5719.187042
# 16            lada    3030.389908
# 17          lancia    3218.629067
# 18      land_rover   16823.683727
# 19           mazda    5796.058619
# 20   mercedes_benz   17614.749292
# 21            mini    9979.384967
# 22      mitsubishi    3298.864700
# 23          nissan    4585.395993
# 24            opel    3248.278325
# 25         peugeot    3206.266310
# ...

# %%
b[b["brand"].isin(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'])]
# Out:
#             brand         price
# 1            audi  16218.259230
# 2             bmw  14798.226103
# 10           ford   8702.476063
# 20  mercedes_benz  17614.749292
# 24           opel   3248.278325
# 38     volkswagen  13643.476728

# %%
b[b["brand"].isin(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford'])].sort_values(by="price")
# Out:
#             brand         price
# 24           opel   3248.278325
# 10           ford   8702.476063
# 38     volkswagen  13643.476728
# 2             bmw  14798.226103
# 1            audi  16218.259230
# 20  mercedes_benz  17614.749292

# %% [markdown]
# 1. Audi, BMW and Mercedes Benz are more expensive
#
# 2. Ford and Opel are less expensive
#
# 3. Volkswagen is in between

# %% [markdown]
# ## 7. Identify categorical data that uses german words, translate them and map the values to their english counterparts

# %%
new_df["seller"].unique()   #privat and gewerblich are german words
# Out:
# array(['privat', 'gewerblich'], dtype=object)

# %%
new_df["seller"]=new_df["seller"].map({"privat":"private", "gewerblich":"commercial"})
# Out:
# C:\Users\prash\AppData\Local\Temp\ipykernel_12964\2990295066.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["seller"]=new_df["seller"].map({"privat":"private", "gewerblich":"commercial"})

# %%
new_df
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#          seller offerType  price   abtest vehicleType  registration_year  \
# ...

# %%
new_df["offerType"].unique()
# Out:
# array(['Angebot', 'Gesuch'], dtype=object)

# %%
new_df.nunique()
# Out:
# dateCrawled           272527
# name                  222012
# seller                     2
# offerType                  2
# price                   5552
# abtest                     2
# vehicleType                8
# registration_year         97
# gearbox                    2
# powerPS                  782
# model                    251
# odometer_km               13
# registration_month        13
# fuelType                   7
# brand                     40
# unrepaired_damage          2
# ad_created               113
# nrOfPictures               1
# postalCode              8145
# lastSeen              176808
# dtype: int64

# %% [markdown]
# ## 8.Find the most common brand/model combinations

# %%
new_df.groupby(["brand","model"])["dateCrawled"].count().reset_index().sort_values(by="dateCrawled",ascending=False).head(20)
# Out:
#              brand        model  dateCrawled
# 275     volkswagen         golf        28432
# 23             bmw          3er        20026
# 281     volkswagen         polo        12477
# 189           opel        corsa        11941
# 186           opel        astra        10357
# 13            audi           a4        10053
# 279     volkswagen       passat        10003
# 148  mercedes_benz     c_klasse         8574
# 24             bmw          5er         8398
# 151  mercedes_benz     e_klasse         7412
# 12            audi           a3         6242
# 15            audi           a6         5903
# 82            ford        focus         5707
# 81            ford       fiesta         5551
# 287     volkswagen  transporter         5366
# 200        peugeot      2_reihe         4699
# 218        renault       twingo         4645
# 246          smart       fortwo         4190
# 196           opel       vectra         4098
# 145  mercedes_benz     a_klasse         4039

# %%
new_df
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#          seller offerType  price   abtest vehicleType  registration_year  \
# ...

# %% [markdown]
# ## 9.How much cheaper are cars with damage than their non-damaged counterparts?

# %%
new_df["unrepaired_damage"].isna().sum()
# Out:
# 65661

# %%
new_df["unrepaired_damage"].unique() #ja and nein are german words
# Out:
# array([nan, 'ja', 'nein'], dtype=object)

# %%
new_df["unrepaired_damage"].map({"ja":"yes","nein":"no"})
# Out:
# 0         NaN
# 1         yes
# 2         NaN
# 3          no
# 4          no
#          ...
# 371523    NaN
# 371524     no
# 371525     no
# 371526    NaN
# 371527     no
# Name: unrepaired_damage, Length: 356780, dtype: object

# %%
new_df["unrepaired_damage"] = new_df["unrepaired_damage"].map({"ja":"yes","nein":"no"})
new_df
# Out:
# C:\Users\prash\AppData\Local\Temp\ipykernel_12964\3613448828.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["unrepaired_damage"] = new_df["unrepaired_damage"].map({"ja":"yes","nein":"no"})
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# ...

# %%
new_df.groupby("unrepaired_damage")["price"].count()
# Out:
# unrepaired_damage
# no     256002
# yes     35117
# Name: price, dtype: int64

# %%
new_df.groupby("unrepaired_damage")["price"].sum()
# Out:
# unrepaired_damage
# no     2360366684
# yes    2369407612
# Name: price, dtype: int64
