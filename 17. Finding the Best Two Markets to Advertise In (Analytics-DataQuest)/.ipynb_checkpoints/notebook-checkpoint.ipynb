# %% [markdown]
# Let's assume that we're working for an an e-learning company that offers courses on programming. Most of our courses are on web and mobile development, but we also cover many other domains, like data science, game development, etc. We want to promote our product and we'd like to invest some money in advertisement. Our goal in this project is to find out the two best markets to advertise our product in.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("2017-fCC-New-Coders-Survey-Data.csv")
df
# Out:
# C:\Users\prash\AppData\Local\Temp\ipykernel_10320\1777024333.py:1: DtypeWarning: Columns (17,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("2017-fCC-New-Coders-Survey-Data.csv")
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0      27.0               0.0             NaN                NaN          NaN
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 3      26.0               0.0             NaN                NaN          NaN
# 4      20.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18170  41.0               0.0             NaN                NaN          NaN
# 18171  31.0               0.0             NaN                NaN          NaN
# 18172  39.0               0.0             NaN                NaN          NaN
# 18173  54.0               0.0             NaN                NaN          NaN
# 18174  50.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                    NaN             NaN            more than 1 million
# 1                    NaN             NaN              less than 100,000
# 2                    NaN             NaN            more than 1 million
# 3                    NaN             NaN  between 100,000 and 1 million
# 4                    NaN             NaN  between 100,000 and 1 million
# ...                  ...             ...                            ...
# 18170                NaN             1.0            more than 1 million
# 18171                NaN             1.0            more than 1 million
# 18172                NaN             3.0            more than 1 million
# 18173                NaN             3.0  between 100,000 and 1 million
# 18174                NaN             2.0              less than 100,000
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFCC  \
# 0                       NaN                   NaN  ...         NaN
# 1                       NaN                   NaN  ...         1.0
# 2                       NaN                   NaN  ...         NaN
# 3                       NaN                   NaN  ...         1.0
# 4                       NaN                   NaN  ...         NaN
# ...                     ...                   ...  ...         ...
# 18170                   NaN                   NaN  ...         NaN
# 18171                   NaN                   NaN  ...         1.0
# 18172                   NaN                   NaN  ...         1.0
# 18173                   NaN                   NaN  ...         1.0
# 18174                   NaN                   NaN  ...         NaN
#
#        YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# 0                        NaN               NaN               NaN
# 1                        NaN               NaN               NaN
# 2                        NaN               NaN               1.0
# 3                        1.0               NaN               NaN
# 4                        NaN               NaN               NaN
# ...                      ...               ...               ...
# 18170                    NaN               NaN               NaN
# 18171                    NaN               NaN               NaN
# 18172                    NaN               NaN               NaN
# 18173                    NaN               NaN               1.0
# 18174                    NaN               NaN               NaN
#
#        YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks YouTubeOther  \
# 0                     NaN         NaN                  NaN          NaN
# 1                     NaN         NaN                  NaN          NaN
# 2                     1.0         NaN                  NaN          NaN
# 3                     1.0         NaN                  NaN          NaN
# 4                     NaN         NaN                  NaN          NaN
# ...                   ...         ...                  ...          ...
# 18170                 NaN         NaN                  NaN    never see
# 18171                 NaN         NaN                  NaN          NaN
# 18172                 NaN         NaN                  NaN          NaN
# 18173                 NaN         NaN                  1.0          NaN
# 18174                 NaN         NaN                  NaN          NaN
#
#        YouTubeSimplilearn  YouTubeTheNewBoston
# 0                     NaN                  NaN
# 1                     NaN                  NaN
# 2                     NaN                  NaN
# 3                     NaN                  NaN
# 4                     NaN                  NaN
# ...                   ...                  ...
# 18170                 NaN                  NaN
# 18171                 NaN                  NaN
# 18172                 NaN                  1.0
# 18173                 NaN                  NaN
# 18174                 NaN                  NaN
#
# [18175 rows x 136 columns]

# %%
print(df.isna().sum().to_string())
# Out:
# Age                               2808
# AttendedBootcamp                   466
# BootcampFinish                   17106
# BootcampLoanYesNo                17096
# BootcampName                     17226
# BootcampRecommend                17102
# ChildrenNumber                   15861
# CityPopulation                    2821
# CodeEventConferences             16566
# CodeEventDjangoGirls             18010
# CodeEventFCC                     16467
# CodeEventGameJam                 17885
# CodeEventGirlDev                 17878
# CodeEventHackathons              16198
# CodeEventMeetup                  15703
# CodeEventNodeSchool              17729
# CodeEventNone                    17099
# CodeEventOther                   17605
# CodeEventRailsBridge             18042
# CodeEventRailsGirls              18043
# CodeEventStartUpWknd             17631
# CodeEventWkdBootcamps            17628
# CodeEventWomenCode               17694
# CodeEventWorkshops               16422
# CommuteTime                       8929
# CountryCitizen                    2793
# CountryLive                       2839
# EmploymentField                  10059
# EmploymentFieldOther             17097
# EmploymentStatus                  3830
# EmploymentStatusOther            17342
# ExpectedEarning                  10975
# FinanciallySupporting            14342
# FirstDevJob                      13667
# Gender                            2721
# GenderOther                      18120
# HasChildren                      14317
# HasDebt                           2884
# HasFinancialDependents            2846
# HasHighSpdInternet                2795
# HasHomeMortgage                  11778
# HasServedInMilitary               2919
# HasStudentDebt                   11773
# HomeMortgageOwe                  16804
# HoursLearning                     1461
# ID.x                                 0
# ID.y                              2432
# Income                           10552
# IsEthnicMinority                  2882
# IsReceiveDisabilitiesBenefits     2953
# IsSoftwareDev                      107
# IsUnderEmployed                   8952
# JobApplyWhen                     10037
# JobInterestBackEnd               14974
# JobInterestDataEngr              16705
# JobInterestDataSci               16235
# JobInterestDevOps                17083
# JobInterestFrontEnd              14128
# JobInterestFullStack             13344
# JobInterestGameDev               16300
# JobInterestInfoSec               16615
# JobInterestMobile                15498
# JobInterestOther                 17909
# JobInterestProjMngr              17236
# JobInterestQAEngr                17591
# JobInterestUX                    16484
# JobPref                           4692
# JobRelocateYesNo                 11672
# JobRoleInterest                  11183
# JobWherePref                     10057
# LanguageAtHome                    2831
# MaritalStatus                     2840
# MoneyForLearning                  1598
# MonthsProgramming                 1091
# NetworkID                            0
# Part1EndTime                         0
# Part1StartTime                       0
# Part2EndTime                      2432
# Part2StartTime                    2432
# PodcastChangeLog                 17772
# PodcastCodeNewbie                16539
# PodcastCodePen                   17402
# PodcastDevTea                    17447
# PodcastDotNET                    17848
# PodcastGiantRobots               17988
# PodcastJSAir                     17449
# PodcastJSJabber                  17052
# PodcastNone                      17114
# PodcastOther                     17325
# PodcastProgThrowdown             17830
# PodcastRubyRogues                17842
# PodcastSEDaily                   17385
# PodcastSERadio                   17767
# PodcastShopTalk                  17857
# PodcastTalkPython                17520
# PodcastTheWebAhead               17864
# ResourceCodecademy                8785
# ResourceCodeWars                 16327
# ResourceCoursera                 13773
# ResourceCSS                      13504
# ResourceEdX                      14932
# ResourceEgghead                  16834
# ResourceFCC                       4372
# ResourceHackerRank               16126
# ResourceKA                       14375
# ResourceLynda                    15617
# ResourceMDN                      11758
# ResourceOdinProj                 17199
# ResourceOther                    17153
# ResourcePluralSight              15783
# ResourceSkillcrush               17723
# ResourceSO                        6968
# ResourceTreehouse                15915
# ResourceUdacity                  14338
# ResourceUdemy                    13055
# ResourceW3S                       8410
# SchoolDegree                      2807
# SchoolMajor                       9448
# StudentDebtOwe                   14813
# YouTubeCodeCourse                17219
# YouTubeCodingTrain               17199
# YouTubeCodingTut360              16778
# YouTubeComputerphile             16722
# YouTubeDerekBanas                16328
# YouTubeDevTips                   15556
# YouTubeEngineeredTruth           17182
# YouTubeFCC                       12139
# YouTubeFunFunFunction            16914
# YouTubeGoogleDev                 14636
# YouTubeLearnCode                 15513
# YouTubeLevelUpTuts               16779
# YouTubeMIT                       14848
# YouTubeMozillaHacks              17553
# YouTubeOther                     17027
# YouTubeSimplilearn               17974
# YouTubeTheNewBoston              15215

# %% [markdown]
# ## 1.Checking for Sample Representativity

# %% [markdown]
# * Figure out whether the sample we have is representative for our population of interest.
#     * The JobRoleInterest column describes for every participant the role(s) they'd be interested in working.
#     * Generate a frequency distribution table for this column. Take percentages instead of absolute frequencies.
#     * Analyze the table.
#         * Are people interested in only one subject or they can be interested in more than one subject?
#         * If most people are interested in more than one subject, is this sample still representative?
#         * The focus of our courses is on web and mobile development. How many people are interested in at least one of these two subjects?
#
#     * Generate at least one graph while you're working on these steps to help the reader understand easier what you're doing.

# %%
df["JobRoleInterest"].unique()
# Out:
# array([nan, 'Full-Stack Web Developer',
#        '  Front-End Web Developer, Back-End Web Developer,   DevOps / SysAdmin,   Mobile Developer, Full-Stack Web Developer',
#        ...,
#        '  Data Scientist, Game Developer,   Quality Assurance Engineer',
#        'Back-End Web Developer, Data Engineer,   Data Scientist,   DevOps / SysAdmin',
#        '  DevOps / SysAdmin,   Mobile Developer,   Product Manager, Game Developer,   Front-End Web Developer, Data Engineer,   Quality Assurance Engineer,   User Experience Designer, Back-End Web Developer,   Data Scientist, Full-Stack Web Developer, Information Security, IT specialist '],
#       dtype=object)

# %%
df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN            more than 1 million
# 1                NaN             NaN              less than 100,000
# 2                NaN             NaN            more than 1 million
# 3                NaN             NaN  between 100,000 and 1 million
# 4                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFCC  \
# 0                   NaN                   NaN  ...         NaN
# 1                   NaN                   NaN  ...         1.0
# 2                   NaN                   NaN  ...         NaN
# 3                   NaN                   NaN  ...         1.0
# 4                   NaN                   NaN  ...         NaN
#
#    YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# 0                    NaN               NaN               NaN
# 1                    NaN               NaN               NaN
# 2                    NaN               NaN               1.0
# 3                    1.0               NaN               NaN
# 4                    NaN               NaN               NaN
#
#    YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks YouTubeOther  \
# 0                 NaN         NaN                  NaN          NaN
# 1                 NaN         NaN                  NaN          NaN
# 2                 1.0         NaN                  NaN          NaN
# 3                 1.0         NaN                  NaN          NaN
# 4                 NaN         NaN                  NaN          NaN
#
#    YouTubeSimplilearn  YouTubeTheNewBoston
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
#
# [5 rows x 136 columns]

# %%
a=df.groupby("JobRoleInterest")["Age"].count().reset_index().sort_values(by="Age",ascending=False)
a
# Out:
#                                         JobRoleInterest  Age
# 2216                           Full-Stack Web Developer  802
# 428                             Front-End Web Developer  440
# 0                                        Data Scientist  145
# 1602                             Back-End Web Developer  140
# 2677                                     Game Developer  114
# ...                                                 ...  ...
# 2557  Full-Stack Web Developer, Back-End Web Develop...    0
# 866     Mobile Developer,   DevOps / SysAdmin, Data ...    0
# 3145                Information Security, network admin    0
# 1358    Quality Assurance Engineer, Data Engineer, I...    0
# 2712  Game Developer,   Front-End Web Developer,   M...    0
#
# [3213 rows x 2 columns]

# %%
a["percentage"]=a["Age"]/len(df)*100

# %%
a
# Out:
#                                         JobRoleInterest  Age  percentage
# 2216                           Full-Stack Web Developer  802    4.412655
# 428                             Front-End Web Developer  440    2.420908
# 0                                        Data Scientist  145    0.797799
# 1602                             Back-End Web Developer  140    0.770289
# 2677                                     Game Developer  114    0.627235
# ...                                                 ...  ...         ...
# 2557  Full-Stack Web Developer, Back-End Web Develop...    0    0.000000
# 866     Mobile Developer,   DevOps / SysAdmin, Data ...    0    0.000000
# 3145                Information Security, network admin    0    0.000000
# 1358    Quality Assurance Engineer, Data Engineer, I...    0    0.000000
# 2712  Game Developer,   Front-End Web Developer,   M...    0    0.000000
#
# [3213 rows x 3 columns]

# %% [markdown]
# * Are people interested in only one subject or they can be interested in more than one subject?

# %%
def sub(x):
    return len(x.split(","))

# %%
a[">= one subject"]=a["JobRoleInterest"].apply(sub)
a.head()
# Out:
#                 JobRoleInterest  Age  percentage  >= one subject
# 2216   Full-Stack Web Developer  802    4.412655               1
# 428     Front-End Web Developer  440    2.420908               1
# 0                Data Scientist  145    0.797799               1
# 1602     Back-End Web Developer  140    0.770289               1
# 2677             Game Developer  114    0.627235               1

# %%
a[a[">= one subject"]>1]["Age"].sum()
# Out:
# 4689

# %%
len(df)
# Out:
# 18175

# %% [markdown]
# Therefore total of 4689 are interested in more than one subject out of 18175

# %% [markdown]
# * The focus of our courses is on web and mobile development. How many people are interested in at least one of these two subjects?

# %%
def web(x):
    try:
        if np.isnan(x):
            return np.nan
    except:
        
        if "web" in x.lower():
            return True
        else:
            return False

# %%
np.isnan(np.nan)
# Out:
# True

# %%
df["JobRoleInterest"].sample(1)
# Out:
# 9613    NaN
# Name: JobRoleInterest, dtype: object

# %%
df[df["JobRoleInterest"].apply(web)==True]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 3      26.0               0.0             NaN                NaN          NaN
# 4      20.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18157  32.0               0.0             NaN                NaN          NaN
# 18161  32.0               0.0             NaN                NaN          NaN
# 18163  57.0               0.0             NaN                NaN          NaN
# 18171  31.0               0.0             NaN                NaN          NaN
# 18174  50.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 1                    NaN             NaN              less than 100,000
# 2                    NaN             NaN            more than 1 million
# 3                    NaN             NaN  between 100,000 and 1 million
# 4                    NaN             NaN  between 100,000 and 1 million
# 6                    NaN             NaN  between 100,000 and 1 million
# ...                  ...             ...                            ...
# 18157                NaN             1.0  between 100,000 and 1 million
# 18161                NaN             2.0            more than 1 million
# 18163                NaN             1.0            more than 1 million
# 18171                NaN             1.0            more than 1 million
# 18174                NaN             2.0              less than 100,000
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFCC  \
# 1                       NaN                   NaN  ...         1.0
# 2                       NaN                   NaN  ...         NaN
# 3                       NaN                   NaN  ...         1.0
# 4                       NaN                   NaN  ...         NaN
# 6                       1.0                   NaN  ...         NaN
# ...                     ...                   ...  ...         ...
# 18157                   NaN                   NaN  ...         NaN
# 18161                   NaN                   NaN  ...         NaN
# 18163                   NaN                   NaN  ...         NaN
# 18171                   NaN                   NaN  ...         1.0
# 18174                   NaN                   NaN  ...         NaN
#
#        YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# 1                        NaN               NaN               NaN
# 2                        NaN               NaN               1.0
# 3                        1.0               NaN               NaN
# 4                        NaN               NaN               NaN
# 6                        NaN               NaN               NaN
# ...                      ...               ...               ...
# 18157                    NaN               NaN               NaN
# 18161                    NaN               NaN               NaN
# 18163                    NaN               NaN               NaN
# 18171                    NaN               NaN               NaN
# 18174                    NaN               NaN               NaN
#
#        YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks YouTubeOther  \
# 1                     NaN         NaN                  NaN          NaN
# 2                     1.0         NaN                  NaN          NaN
# 3                     1.0         NaN                  NaN          NaN
# 4                     NaN         NaN                  NaN          NaN
# 6                     NaN         NaN                  NaN          NaN
# ...                   ...         ...                  ...          ...
# 18157                 NaN         NaN                  NaN          NaN
# 18161                 NaN         NaN                  NaN          NaN
# 18163                 NaN         NaN                  NaN          NaN
# 18171                 NaN         NaN                  NaN          NaN
# 18174                 NaN         NaN                  NaN          NaN
#
#        YouTubeSimplilearn  YouTubeTheNewBoston
# 1                     NaN                  NaN
# 2                     NaN                  NaN
# 3                     NaN                  NaN
# 4                     NaN                  NaN
# 6                     NaN                  NaN
# ...                   ...                  ...
# 18157                 NaN                  NaN
# 18161                 NaN                  NaN
# 18163                 NaN                  NaN
# 18171                 NaN                  NaN
# 18174                 NaN                  NaN
#
# [5781 rows x 136 columns]

# %% [markdown]
# 5781--web development

# %%
def mob(x):
    try:
        if np.isnan(x):
            return np.nan
    except:
        
        if "mobile" in x.lower():
            return True
        else:
            return False

# %%
df[df["JobRoleInterest"].apply(mob)==True]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 2      21.0               0.0             NaN                NaN          NaN
# 4      20.0               0.0             NaN                NaN          NaN
# 19     31.0               0.0             NaN                NaN          NaN
# 29     27.0               0.0             NaN                NaN          NaN
# 37     37.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18113  24.0               0.0             NaN                NaN          NaN
# 18118  36.0               0.0             NaN                NaN          NaN
# 18129  55.0               0.0             NaN                NaN          NaN
# 18157  32.0               0.0             NaN                NaN          NaN
# 18171  31.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 2                    NaN             NaN            more than 1 million
# 4                    NaN             NaN  between 100,000 and 1 million
# 19                   NaN             NaN              less than 100,000
# 29                   NaN             NaN  between 100,000 and 1 million
# 37                   NaN             NaN  between 100,000 and 1 million
# ...                  ...             ...                            ...
# 18113                NaN             2.0  between 100,000 and 1 million
# 18118                NaN             4.0              less than 100,000
# 18129                NaN             4.0              less than 100,000
# 18157                NaN             1.0  between 100,000 and 1 million
# 18171                NaN             1.0            more than 1 million
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFCC  \
# 2                       NaN                   NaN  ...         NaN
# 4                       NaN                   NaN  ...         NaN
# 19                      NaN                   NaN  ...         NaN
# 29                      NaN                   NaN  ...         1.0
# 37                      NaN                   NaN  ...         NaN
# ...                     ...                   ...  ...         ...
# 18113                   NaN                   NaN  ...         NaN
# 18118                   NaN                   NaN  ...         1.0
# 18129                   NaN                   NaN  ...         NaN
# 18157                   NaN                   NaN  ...         NaN
# 18171                   NaN                   NaN  ...         1.0
#
#        YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# 2                        NaN               NaN               1.0
# 4                        NaN               NaN               NaN
# 19                       NaN               NaN               NaN
# 29                       NaN               1.0               NaN
# 37                       NaN               NaN               NaN
# ...                      ...               ...               ...
# 18113                    NaN               NaN               1.0
# 18118                    NaN               NaN               NaN
# 18129                    NaN               NaN               NaN
# 18157                    NaN               NaN               NaN
# 18171                    NaN               NaN               NaN
#
#        YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks YouTubeOther  \
# 2                     1.0         NaN                  NaN          NaN
# 4                     NaN         NaN                  NaN          NaN
# 19                    NaN         NaN                  NaN          NaN
# 29                    NaN         NaN                  NaN          NaN
# 37                    NaN         NaN                  NaN          NaN
# ...                   ...         ...                  ...          ...
# 18113                 NaN         NaN                  NaN          NaN
# 18118                 NaN         NaN                  NaN          NaN
# 18129                 NaN         NaN                  NaN          NaN
# 18157                 NaN         NaN                  NaN          NaN
# 18171                 NaN         NaN                  NaN          NaN
#
#        YouTubeSimplilearn  YouTubeTheNewBoston
# 2                     NaN                  NaN
# 4                     NaN                  NaN
# 19                    NaN                  NaN
# 29                    NaN                  NaN
# 37                    NaN                  NaN
# ...                   ...                  ...
# 18113                 NaN                  NaN
# 18118                 NaN                  NaN
# 18129                 NaN                  NaN
# 18157                 NaN                  NaN
# 18171                 NaN                  NaN
#
# [2305 rows x 136 columns]

# %% [markdown]
# 2305 -- mobile development

# %%
2305+5781
# Out:
# 8086

# %%
df[(df["JobRoleInterest"].apply(mob)==True) | (df["JobRoleInterest"].apply(web)==True)]
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 3      26.0               0.0             NaN                NaN          NaN
# 4      20.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18157  32.0               0.0             NaN                NaN          NaN
# 18161  32.0               0.0             NaN                NaN          NaN
# 18163  57.0               0.0             NaN                NaN          NaN
# 18171  31.0               0.0             NaN                NaN          NaN
# 18174  50.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 1                    NaN             NaN              less than 100,000
# 2                    NaN             NaN            more than 1 million
# 3                    NaN             NaN  between 100,000 and 1 million
# 4                    NaN             NaN  between 100,000 and 1 million
# 6                    NaN             NaN  between 100,000 and 1 million
# ...                  ...             ...                            ...
# 18157                NaN             1.0  between 100,000 and 1 million
# 18161                NaN             2.0            more than 1 million
# 18163                NaN             1.0            more than 1 million
# 18171                NaN             1.0            more than 1 million
# 18174                NaN             2.0              less than 100,000
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFCC  \
# 1                       NaN                   NaN  ...         1.0
# 2                       NaN                   NaN  ...         NaN
# 3                       NaN                   NaN  ...         1.0
# 4                       NaN                   NaN  ...         NaN
# 6                       1.0                   NaN  ...         NaN
# ...                     ...                   ...  ...         ...
# 18157                   NaN                   NaN  ...         NaN
# 18161                   NaN                   NaN  ...         NaN
# 18163                   NaN                   NaN  ...         NaN
# 18171                   NaN                   NaN  ...         1.0
# 18174                   NaN                   NaN  ...         NaN
#
#        YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# 1                        NaN               NaN               NaN
# 2                        NaN               NaN               1.0
# 3                        1.0               NaN               NaN
# 4                        NaN               NaN               NaN
# 6                        NaN               NaN               NaN
# ...                      ...               ...               ...
# 18157                    NaN               NaN               NaN
# 18161                    NaN               NaN               NaN
# 18163                    NaN               NaN               NaN
# 18171                    NaN               NaN               NaN
# 18174                    NaN               NaN               NaN
#
#        YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks YouTubeOther  \
# 1                     NaN         NaN                  NaN          NaN
# 2                     1.0         NaN                  NaN          NaN
# 3                     1.0         NaN                  NaN          NaN
# 4                     NaN         NaN                  NaN          NaN
# 6                     NaN         NaN                  NaN          NaN
# ...                   ...         ...                  ...          ...
# 18157                 NaN         NaN                  NaN          NaN
# 18161                 NaN         NaN                  NaN          NaN
# 18163                 NaN         NaN                  NaN          NaN
# 18171                 NaN         NaN                  NaN          NaN
# 18174                 NaN         NaN                  NaN          NaN
#
#        YouTubeSimplilearn  YouTubeTheNewBoston
# 1                     NaN                  NaN
# 2                     NaN                  NaN
# 3                     NaN                  NaN
# 4                     NaN                  NaN
# 6                     NaN                  NaN
# ...                   ...                  ...
# 18157                 NaN                  NaN
# 18161                 NaN                  NaN
# 18163                 NaN                  NaN
# 18171                 NaN                  NaN
# 18174                 NaN                  NaN
#
# [6035 rows x 136 columns]

# %% [markdown]
# * Generate at least one graph while you're working on these steps to help the reader understand easier what you're doing.

# %%
def web_mob(x):
    try:
        if np.isnan(x):
            return np.nan
    except:
        
        if ("mobile" in x.lower()) & ("web" in x.lower()):
            return "mobile,web"
        
        elif "mobile" in x.lower():
            return "mobile"
        
        elif "web" in x.lower():
            return "web"
    
        else:
            return np.nan

# %%
a=df["JobRoleInterest"].apply(web_mob)
a
# Out:
# 0               NaN
# 1               web
# 2        mobile,web
# 3               web
# 4        mobile,web
#             ...
# 18170           NaN
# 18171    mobile,web
# 18172           NaN
# 18173           NaN
# 18174           web
# Name: JobRoleInterest, Length: 18175, dtype: object

# %%
ax=sns.countplot(x=a)
for bar in ax.containers:
    ax.bar_label(bar)

# %% [markdown]
# ## 2.New Coders - Locations and Densities

# %% [markdown]
# The data set provides information about the location of each participant at a country level. The CountryCitizen variable describes the country of origin for each participant, and the CountryLive variable describes what country each participants lives in (which may be different than the origin country).
#
# For our analysis, we'll work with the CountryLive variable because we're interested where people actually live at the moment when we run the ads. In other words, we're interested where people are located, not where they were born.

# %% [markdown]
# * To make sure you're working with a representative sample, drop all the rows where participants didn't answer what role they are interested in. Where a participant didn't respond, we can't know for sure what their interests are, so it's better if we leave out this category of participants.
# * Generate a frequency table for the CountryLive variable.
#     * Generate both absolute and relative frequencies.
#     * Analyze the results.
#     * Based on the results, what are the two markets you'd choose for advertisement?
#     * Can we stop the analysis here, or we need to go more in depth?

# %%
df["JobRoleInterest"].isna().sum()
# Out:
# 11183

# %%
new_df=df.dropna(subset=["JobRoleInterest"])
new_df
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 3      26.0               0.0             NaN                NaN          NaN
# 4      20.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18161  32.0               0.0             NaN                NaN          NaN
# 18162  26.0               0.0             NaN                NaN          NaN
# 18163  57.0               0.0             NaN                NaN          NaN
# 18171  31.0               0.0             NaN                NaN          NaN
# 18174  50.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 1                    NaN             NaN              less than 100,000
# 2                    NaN             NaN            more than 1 million
# 3                    NaN             NaN  between 100,000 and 1 million
# 4                    NaN             NaN  between 100,000 and 1 million
# 6                    NaN             NaN  between 100,000 and 1 million
# ...                  ...             ...                            ...
# 18161                NaN             2.0            more than 1 million
# 18162                NaN             1.0  between 100,000 and 1 million
# 18163                NaN             1.0            more than 1 million
# 18171                NaN             1.0            more than 1 million
# 18174                NaN             2.0              less than 100,000
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFCC  \
# 1                       NaN                   NaN  ...         1.0
# 2                       NaN                   NaN  ...         NaN
# 3                       NaN                   NaN  ...         1.0
# 4                       NaN                   NaN  ...         NaN
# 6                       1.0                   NaN  ...         NaN
# ...                     ...                   ...  ...         ...
# 18161                   NaN                   NaN  ...         NaN
# 18162                   NaN                   NaN  ...         1.0
# 18163                   NaN                   NaN  ...         NaN
# 18171                   NaN                   NaN  ...         1.0
# 18174                   NaN                   NaN  ...         NaN
#
#        YouTubeFunFunFunction  YouTubeGoogleDev  YouTubeLearnCode  \
# 1                        NaN               NaN               NaN
# 2                        NaN               NaN               1.0
# 3                        1.0               NaN               NaN
# 4                        NaN               NaN               NaN
# 6                        NaN               NaN               NaN
# ...                      ...               ...               ...
# 18161                    NaN               NaN               NaN
# 18162                    NaN               1.0               NaN
# 18163                    NaN               NaN               NaN
# 18171                    NaN               NaN               NaN
# 18174                    NaN               NaN               NaN
#
#        YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks YouTubeOther  \
# 1                     NaN         NaN                  NaN          NaN
# 2                     1.0         NaN                  NaN          NaN
# 3                     1.0         NaN                  NaN          NaN
# 4                     NaN         NaN                  NaN          NaN
# 6                     NaN         NaN                  NaN          NaN
# ...                   ...         ...                  ...          ...
# 18161                 NaN         NaN                  NaN          NaN
# 18162                 NaN         NaN                  NaN          NaN
# 18163                 NaN         NaN                  NaN          NaN
# 18171                 NaN         NaN                  NaN          NaN
# 18174                 NaN         NaN                  NaN          NaN
#
#        YouTubeSimplilearn  YouTubeTheNewBoston
# 1                     NaN                  NaN
# 2                     NaN                  NaN
# 3                     NaN                  NaN
# 4                     NaN                  NaN
# 6                     NaN                  NaN
# ...                   ...                  ...
# 18161                 NaN                  NaN
# 18162                 NaN                  NaN
# 18163                 NaN                  NaN
# 18171                 NaN                  NaN
# 18174                 NaN                  NaN
#
# [6992 rows x 136 columns]

# %%
a=new_df.groupby("CountryLive")["Age"].count().reset_index()
a.rename(columns={"Age":"absolute freq"},inplace=True)
a=a.sort_values(by="absolute freq",ascending=False)
a["relative freq"]=a["absolute freq"]/a["absolute freq"].sum()
a
# Out:
#                   CountryLive  absolute freq  relative freq
# 128  United States of America           3075       0.455421
# 54                      India            519       0.076866
# 127            United Kingdom            311       0.046060
# 21                     Canada            258       0.038211
# 96                     Poland            131       0.019402
# ..                        ...            ...            ...
# 46                 Guadeloupe              1       0.000148
# 43                  Gibraltar              1       0.000148
# 111                   Somalia              1       0.000148
# 115                     Sudan              0       0.000000
# 23            Channel Islands              0       0.000000
#
# [137 rows x 3 columns]

# %% [markdown]
# ## 3.Spending Money for Learning

# %% [markdown]
# * Previously, we found useful information about the location of new coders, and what are the countries where new coders live, but we need to go more in depth with our analysis before taking a decision. We can continue by figuring out how much money new coders are actually willing to spend on learning. Advertising within markets where most people are only willing to learn for free is extremely unlikely to be profitable for us.
#
# * The MoneyForLearning column describes in American dollars the amount of money spent by participants from the moment they started coding until the moment they completed the survey. Our company sells subscriptions at a price of 59 dollars per month, and for this reason we're interested in finding out how much money each student spends per month.
#
# * It also seems like a good idea to narrow down our analysis to only four countries: the US, India, the United Kingdom, and Canada. Two reasons for this decision are:
#
#     * These are the countries having the highest absolute frequencies in our sample, which means we have a decent amount of data for each.
#     * Our courses are written in English, and English is an official language in all these four countries. The more people that know English, the better our chances to target the right people with our ads.

# %%
new_df["MoneyForLearning"]
# Out:
# 1           80.0
# 2         1000.0
# 3            0.0
# 4            0.0
# 6            0.0
#           ...
# 18161        0.0
# 18162        0.0
# 18163        0.0
# 18171    10000.0
# 18174        NaN
# Name: MoneyForLearning, Length: 6992, dtype: float64

# %% [markdown]
# 1. Create a new column that describes the amount of money a student has spent per month (at the moment they completed the survey).
#
#     * You'll need to divide the MoneyForLearning column to the MonthsProgramming column.
#     * Some students answered that they had been learning to code for 0 months (it might be that they had just started when they completed the survey). To avoid dividing by 0, replace all the values of 0 with 1.

# %%
new_df.replace({'MonthsProgramming':0},1,inplace=True)
# Out:
# C:\Users\prash\AppData\Local\Temp\ipykernel_10320\410272487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.replace({'MonthsProgramming':0},1,inplace=True)

# %%
(new_df["MonthsProgramming"]==0).any()
# Out:
# False

# %%
new_df["money_per_month"]=new_df["MoneyForLearning"]/new_df["MonthsProgramming"]
new_df
# Out:
# C:\Users\prash\AppData\Local\Temp\ipykernel_10320\3609517622.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["money_per_month"]=new_df["MoneyForLearning"]/new_df["MonthsProgramming"]
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 3      26.0               0.0             NaN                NaN          NaN
# 4      20.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18161  32.0               0.0             NaN                NaN          NaN
# 18162  26.0               0.0             NaN                NaN          NaN
# 18163  57.0               0.0             NaN                NaN          NaN
# 18171  31.0               0.0             NaN                NaN          NaN
# 18174  50.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 1                    NaN             NaN              less than 100,000
# 2                    NaN             NaN            more than 1 million
# 3                    NaN             NaN  between 100,000 and 1 million
# 4                    NaN             NaN  between 100,000 and 1 million
# 6                    NaN             NaN  between 100,000 and 1 million
# ...                  ...             ...                            ...
# 18161                NaN             2.0            more than 1 million
# 18162                NaN             1.0  between 100,000 and 1 million
# 18163                NaN             1.0            more than 1 million
# 18171                NaN             1.0            more than 1 million
# 18174                NaN             2.0              less than 100,000
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFunFunFunction  \
# 1                       NaN                   NaN  ...                    NaN
# 2                       NaN                   NaN  ...                    NaN
# 3                       NaN                   NaN  ...                    1.0
# 4                       NaN                   NaN  ...                    NaN
# 6                       1.0                   NaN  ...                    NaN
# ...                     ...                   ...  ...                    ...
# 18161                   NaN                   NaN  ...                    NaN
# 18162                   NaN                   NaN  ...                    NaN
# 18163                   NaN                   NaN  ...                    NaN
# 18171                   NaN                   NaN  ...                    NaN
# 18174                   NaN                   NaN  ...                    NaN
#
#        YouTubeGoogleDev  YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  \
# 1                   NaN               NaN                 NaN         NaN
# 2                   NaN               1.0                 1.0         NaN
# 3                   NaN               NaN                 1.0         NaN
# 4                   NaN               NaN                 NaN         NaN
# 6                   NaN               NaN                 NaN         NaN
# ...                 ...               ...                 ...         ...
# 18161               NaN               NaN                 NaN         NaN
# 18162               1.0               NaN                 NaN         NaN
# 18163               NaN               NaN                 NaN         NaN
# 18171               NaN               NaN                 NaN         NaN
# 18174               NaN               NaN                 NaN         NaN
#
#        YouTubeMozillaHacks  YouTubeOther YouTubeSimplilearn  \
# 1                      NaN           NaN                NaN
# 2                      NaN           NaN                NaN
# 3                      NaN           NaN                NaN
# 4                      NaN           NaN                NaN
# 6                      NaN           NaN                NaN
# ...                    ...           ...                ...
# 18161                  NaN           NaN                NaN
# 18162                  NaN           NaN                NaN
# 18163                  NaN           NaN                NaN
# 18171                  NaN           NaN                NaN
# 18174                  NaN           NaN                NaN
#
#        YouTubeTheNewBoston  money_per_month
# 1                      NaN        13.333333
# 2                      NaN       200.000000
# 3                      NaN         0.000000
# 4                      NaN         0.000000
# 6                      NaN         0.000000
# ...                    ...              ...
# 18161                  NaN         0.000000
# 18162                  NaN         0.000000
# 18163                  NaN              NaN
# 18171                  NaN     10000.000000
# 18174                  NaN              NaN
#
# [6992 rows x 137 columns]

# %% [markdown]
# 2.Find out how many null values there are in the new column (the column describing the amount of money students spend per month).

# %%
new_df["money_per_month"].isna().sum()
# Out:
# 675

# %% [markdown]
# 3.Keep only the rows that don't have a null value for the new column.

# %%
new_df.dropna(subset=["money_per_month"],inplace=True)
# Out:
# C:\Users\prash\AppData\Local\Temp\ipykernel_10320\3007253949.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.dropna(subset=["money_per_month"],inplace=True)

# %%
new_df
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 3      26.0               0.0             NaN                NaN          NaN
# 4      20.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18157  32.0               0.0             NaN                NaN          NaN
# 18160  62.0               0.0             NaN                NaN          NaN
# 18161  32.0               0.0             NaN                NaN          NaN
# 18162  26.0               0.0             NaN                NaN          NaN
# 18171  31.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 1                    NaN             NaN              less than 100,000
# 2                    NaN             NaN            more than 1 million
# 3                    NaN             NaN  between 100,000 and 1 million
# 4                    NaN             NaN  between 100,000 and 1 million
# 6                    NaN             NaN  between 100,000 and 1 million
# ...                  ...             ...                            ...
# 18157                NaN             1.0  between 100,000 and 1 million
# 18160                NaN             1.0            more than 1 million
# 18161                NaN             2.0            more than 1 million
# 18162                NaN             1.0  between 100,000 and 1 million
# 18171                NaN             1.0            more than 1 million
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFunFunFunction  \
# 1                       NaN                   NaN  ...                    NaN
# 2                       NaN                   NaN  ...                    NaN
# 3                       NaN                   NaN  ...                    1.0
# 4                       NaN                   NaN  ...                    NaN
# 6                       1.0                   NaN  ...                    NaN
# ...                     ...                   ...  ...                    ...
# 18157                   NaN                   NaN  ...                    NaN
# 18160                   NaN                   NaN  ...                    NaN
# 18161                   NaN                   NaN  ...                    NaN
# 18162                   NaN                   NaN  ...                    NaN
# 18171                   NaN                   NaN  ...                    NaN
#
#        YouTubeGoogleDev  YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  \
# 1                   NaN               NaN                 NaN         NaN
# 2                   NaN               1.0                 1.0         NaN
# 3                   NaN               NaN                 1.0         NaN
# 4                   NaN               NaN                 NaN         NaN
# 6                   NaN               NaN                 NaN         NaN
# ...                 ...               ...                 ...         ...
# 18157               NaN               NaN                 NaN         NaN
# 18160               NaN               NaN                 NaN         NaN
# 18161               NaN               NaN                 NaN         NaN
# 18162               1.0               NaN                 NaN         NaN
# 18171               NaN               NaN                 NaN         NaN
#
#        YouTubeMozillaHacks  YouTubeOther YouTubeSimplilearn  \
# 1                      NaN           NaN                NaN
# 2                      NaN           NaN                NaN
# 3                      NaN           NaN                NaN
# 4                      NaN           NaN                NaN
# 6                      NaN           NaN                NaN
# ...                    ...           ...                ...
# 18157                  NaN           NaN                NaN
# 18160                  NaN           NaN                NaN
# 18161                  NaN           NaN                NaN
# 18162                  NaN           NaN                NaN
# 18171                  NaN           NaN                NaN
#
#        YouTubeTheNewBoston  money_per_month
# 1                      NaN        13.333333
# 2                      NaN       200.000000
# 3                      NaN         0.000000
# 4                      NaN         0.000000
# 6                      NaN         0.000000
# ...                    ...              ...
# 18157                  NaN         0.000000
# 18160                  NaN        33.333333
# 18161                  NaN         0.000000
# 18162                  NaN         0.000000
# 18171                  NaN     10000.000000
#
# [6317 rows x 137 columns]

# %% [markdown]
# 4.Remove also any rows that have null values in the CountryLive column.

# %%
new_df.dropna(subset=["CountryLive"],inplace=True)
new_df
# Out:
# C:\Users\prash\AppData\Local\Temp\ipykernel_10320\3586926204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.dropna(subset=["CountryLive"],inplace=True)
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 3      26.0               0.0             NaN                NaN          NaN
# 4      20.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18157  32.0               0.0             NaN                NaN          NaN
# 18160  62.0               0.0             NaN                NaN          NaN
# 18161  32.0               0.0             NaN                NaN          NaN
# 18162  26.0               0.0             NaN                NaN          NaN
# 18171  31.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 1                    NaN             NaN              less than 100,000
# 2                    NaN             NaN            more than 1 million
# 3                    NaN             NaN  between 100,000 and 1 million
# 4                    NaN             NaN  between 100,000 and 1 million
# 6                    NaN             NaN  between 100,000 and 1 million
# ...                  ...             ...                            ...
# 18157                NaN             1.0  between 100,000 and 1 million
# 18160                NaN             1.0            more than 1 million
# 18161                NaN             2.0            more than 1 million
# 18162                NaN             1.0  between 100,000 and 1 million
# 18171                NaN             1.0            more than 1 million
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFunFunFunction  \
# 1                       NaN                   NaN  ...                    NaN
# 2                       NaN                   NaN  ...                    NaN
# 3                       NaN                   NaN  ...                    1.0
# 4                       NaN                   NaN  ...                    NaN
# 6                       1.0                   NaN  ...                    NaN
# ...                     ...                   ...  ...                    ...
# 18157                   NaN                   NaN  ...                    NaN
# 18160                   NaN                   NaN  ...                    NaN
# 18161                   NaN                   NaN  ...                    NaN
# 18162                   NaN                   NaN  ...                    NaN
# 18171                   NaN                   NaN  ...                    NaN
#
#        YouTubeGoogleDev  YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  \
# 1                   NaN               NaN                 NaN         NaN
# 2                   NaN               1.0                 1.0         NaN
# 3                   NaN               NaN                 1.0         NaN
# 4                   NaN               NaN                 NaN         NaN
# 6                   NaN               NaN                 NaN         NaN
# ...                 ...               ...                 ...         ...
# 18157               NaN               NaN                 NaN         NaN
# 18160               NaN               NaN                 NaN         NaN
# 18161               NaN               NaN                 NaN         NaN
# 18162               1.0               NaN                 NaN         NaN
# 18171               NaN               NaN                 NaN         NaN
#
#        YouTubeMozillaHacks  YouTubeOther YouTubeSimplilearn  \
# 1                      NaN           NaN                NaN
# 2                      NaN           NaN                NaN
# 3                      NaN           NaN                NaN
# 4                      NaN           NaN                NaN
# 6                      NaN           NaN                NaN
# ...                    ...           ...                ...
# 18157                  NaN           NaN                NaN
# 18160                  NaN           NaN                NaN
# 18161                  NaN           NaN                NaN
# 18162                  NaN           NaN                NaN
# 18171                  NaN           NaN                NaN
#
#        YouTubeTheNewBoston  money_per_month
# 1                      NaN        13.333333
# 2                      NaN       200.000000
# 3                      NaN         0.000000
# 4                      NaN         0.000000
# 6                      NaN         0.000000
# ...                    ...              ...
# 18157                  NaN         0.000000
# 18160                  NaN        33.333333
# 18161                  NaN         0.000000
# 18162                  NaN         0.000000
# 18171                  NaN     10000.000000
#
# [6212 rows x 137 columns]

# %% [markdown]
# 5. Group the remaining data by the CountryLive column and find out how much money a student spends on average each month in the US, India, the United Kingdom and Canada.
#     * You can use the DataFrame.groupby() method.
#     * As a summary metric, we recommend choosing the mean to take into account all values in the distributions. You can also compute the median or the mode to see how they compare with the mean.
#     * Analyze the results. Is there anything in the results that looks off?

# %%
a=new_df.groupby("CountryLive")["money_per_month"].agg(["mean","median"]).sort_values(by="mean",ascending=False).reset_index()
a
# Out:
#      CountryLive          mean        median
# 0          Yemen  10000.000000  10000.000000
# 1    Puerto Rico   4291.394558      7.142857
# 2        Austria    936.208333      4.166667
# 3          Spain    784.553084      5.416667
# 4        Jamaica    747.037037      0.000000
# ..           ...           ...           ...
# 126     Honduras      0.000000      0.000000
# 127       Jordan      0.000000      0.000000
# 128   Mozambique      0.000000      0.000000
# 129       Nambia      0.000000      0.000000
# 130   Kyrgyzstan      0.000000      0.000000
#
# [131 rows x 3 columns]

# %%
a[a["CountryLive"].isin(["India","United States of America","United Kingdom","Canada"])]
# Out:
#                  CountryLive        mean    median
# 22  United States of America  227.997996  3.333333
# 27                     India  135.100982  0.000000
# 30                    Canada  113.510961  0.000000
# 57            United Kingdom   45.534443  0.000000

# %% [markdown]
# ## 4.Dealing with Extreme Outliers

# %% [markdown]
# The results for the United Kingdom and Canada are surprisingly low relative to the values we see for India. If we considered a few socio-economical metrics (like GDP per capita), we'd intuitively expect people in the UK and Canada to spend more on learning than people in India.
#
# It might be that we don't have have enough representative data for the United Kingdom, Canada, and India, or we have some outliers (maybe coming from wrong survey answers) making the mean too big for India, or too low for the UK and Canada. Or it might be that the results are correct.

# %% [markdown]
# 1. Generate four box plots on the same figure to visualize for each country (the US, India, the United Kingdom, Canada) the distribution of the variable that describes how much money each participant had spent per month.
#
#     * Can you spot extreme outliers for India, Canada or the United Kingdom?
#     * If not, what extreme outliers can you spot?

# %%
four=new_df[new_df["CountryLive"].isin(["India","United States of America","United Kingdom","Canada"])]
four
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# 15     32.0               0.0             NaN                NaN          NaN
# 16     29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18107  35.0               0.0             NaN                NaN          NaN
# 18111  30.0               0.0             NaN                NaN          NaN
# 18113  24.0               0.0             NaN                NaN          NaN
# 18130  23.0               0.0             NaN                NaN          NaN
# 18156  29.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 1                    NaN             NaN              less than 100,000
# 2                    NaN             NaN            more than 1 million
# 6                    NaN             NaN  between 100,000 and 1 million
# 15                   NaN             NaN              less than 100,000
# 16                   NaN             NaN  between 100,000 and 1 million
# ...                  ...             ...                            ...
# 18107                NaN             2.0              less than 100,000
# 18111                NaN             1.0            more than 1 million
# 18113                NaN             2.0  between 100,000 and 1 million
# 18130                NaN             1.0  between 100,000 and 1 million
# 18156                NaN             1.0  between 100,000 and 1 million
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFunFunFunction  \
# 1                       NaN                   NaN  ...                    NaN
# 2                       NaN                   NaN  ...                    NaN
# 6                       1.0                   NaN  ...                    NaN
# 15                      NaN                   NaN  ...                    NaN
# 16                      NaN                   NaN  ...                    1.0
# ...                     ...                   ...  ...                    ...
# 18107                   NaN                   NaN  ...                    NaN
# 18111                   NaN                   NaN  ...                    1.0
# 18113                   NaN                   NaN  ...                    NaN
# 18130                   NaN                   NaN  ...                    NaN
# 18156                   NaN                   NaN  ...                    NaN
#
#        YouTubeGoogleDev  YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  \
# 1                   NaN               NaN                 NaN         NaN
# 2                   NaN               1.0                 1.0         NaN
# 6                   NaN               NaN                 NaN         NaN
# 15                  NaN               NaN                 NaN         NaN
# 16                  NaN               NaN                 NaN         NaN
# ...                 ...               ...                 ...         ...
# 18107               1.0               NaN                 NaN         NaN
# 18111               NaN               NaN                 NaN         1.0
# 18113               NaN               1.0                 NaN         NaN
# 18130               1.0               NaN                 NaN         1.0
# 18156               NaN               NaN                 NaN         NaN
#
#        YouTubeMozillaHacks  YouTubeOther YouTubeSimplilearn  \
# 1                      NaN           NaN                NaN
# 2                      NaN           NaN                NaN
# 6                      NaN           NaN                NaN
# 15                     NaN           NaN                NaN
# 16                     NaN           NaN                NaN
# ...                    ...           ...                ...
# 18107                  NaN           NaN                NaN
# 18111                  NaN           NaN                NaN
# 18113                  NaN           NaN                NaN
# 18130                  NaN           NaN                NaN
# 18156                  NaN           NaN                NaN
#
#        YouTubeTheNewBoston  money_per_month
# 1                      NaN        13.333333
# 2                      NaN       200.000000
# 6                      NaN         0.000000
# 15                     NaN         0.000000
# 16                     1.0        16.666667
# ...                    ...              ...
# 18107                  NaN       275.000000
# 18111                  NaN       200.000000
# 18113                  NaN         0.000000
# 18130                  NaN         0.000000
# 18156                  NaN      1000.000000
#
# [3915 rows x 137 columns]

# %%
ax=sns.boxplot(data=four,x="CountryLive",y="money_per_month")
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'United States of America'),
#   Text(1, 0, 'United Kingdom'),
#   Text(2, 0, 'India'),
#   Text(3, 0, 'Canada')])

# %% [markdown]
# It's hard to see on the plot above if there's anything wrong with the data for the United Kingdom, India, or Canada, but we can see immediately that there's something really off for the US: two persons spend each month.

# %%
# Isolate only those participants who spend less than 20000 per month
new_df = new_df[new_df['money_per_month'] < 20000]

# %%
new_df.groupby("CountryLive")["money_per_month"].mean()[['United States of America',
                            'India', 'United Kingdom',
                            'Canada']]
# Out:
# CountryLive
# United States of America    183.800110
# India                       135.100982
# United Kingdom               45.534443
# Canada                      113.510961
# Name: money_per_month, dtype: float64

# %%
four=new_df[new_df["CountryLive"].isin(["India","United States of America","United Kingdom","Canada"])]
four
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# 15     32.0               0.0             NaN                NaN          NaN
# 16     29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18107  35.0               0.0             NaN                NaN          NaN
# 18111  30.0               0.0             NaN                NaN          NaN
# 18113  24.0               0.0             NaN                NaN          NaN
# 18130  23.0               0.0             NaN                NaN          NaN
# 18156  29.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 1                    NaN             NaN              less than 100,000
# 2                    NaN             NaN            more than 1 million
# 6                    NaN             NaN  between 100,000 and 1 million
# 15                   NaN             NaN              less than 100,000
# 16                   NaN             NaN  between 100,000 and 1 million
# ...                  ...             ...                            ...
# 18107                NaN             2.0              less than 100,000
# 18111                NaN             1.0            more than 1 million
# 18113                NaN             2.0  between 100,000 and 1 million
# 18130                NaN             1.0  between 100,000 and 1 million
# 18156                NaN             1.0  between 100,000 and 1 million
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFunFunFunction  \
# 1                       NaN                   NaN  ...                    NaN
# 2                       NaN                   NaN  ...                    NaN
# 6                       1.0                   NaN  ...                    NaN
# 15                      NaN                   NaN  ...                    NaN
# 16                      NaN                   NaN  ...                    1.0
# ...                     ...                   ...  ...                    ...
# 18107                   NaN                   NaN  ...                    NaN
# 18111                   NaN                   NaN  ...                    1.0
# 18113                   NaN                   NaN  ...                    NaN
# 18130                   NaN                   NaN  ...                    NaN
# 18156                   NaN                   NaN  ...                    NaN
#
#        YouTubeGoogleDev  YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  \
# 1                   NaN               NaN                 NaN         NaN
# 2                   NaN               1.0                 1.0         NaN
# 6                   NaN               NaN                 NaN         NaN
# 15                  NaN               NaN                 NaN         NaN
# 16                  NaN               NaN                 NaN         NaN
# ...                 ...               ...                 ...         ...
# 18107               1.0               NaN                 NaN         NaN
# 18111               NaN               NaN                 NaN         1.0
# 18113               NaN               1.0                 NaN         NaN
# 18130               1.0               NaN                 NaN         1.0
# 18156               NaN               NaN                 NaN         NaN
#
#        YouTubeMozillaHacks  YouTubeOther YouTubeSimplilearn  \
# 1                      NaN           NaN                NaN
# 2                      NaN           NaN                NaN
# 6                      NaN           NaN                NaN
# 15                     NaN           NaN                NaN
# 16                     NaN           NaN                NaN
# ...                    ...           ...                ...
# 18107                  NaN           NaN                NaN
# 18111                  NaN           NaN                NaN
# 18113                  NaN           NaN                NaN
# 18130                  NaN           NaN                NaN
# 18156                  NaN           NaN                NaN
#
#        YouTubeTheNewBoston  money_per_month
# 1                      NaN        13.333333
# 2                      NaN       200.000000
# 6                      NaN         0.000000
# 15                     NaN         0.000000
# 16                     1.0        16.666667
# ...                    ...              ...
# 18107                  NaN       275.000000
# 18111                  NaN       200.000000
# 18113                  NaN         0.000000
# 18130                  NaN         0.000000
# 18156                  NaN      1000.000000
#
# [3913 rows x 137 columns]

# %%
ax=sns.boxplot(data=four,x="CountryLive",y="money_per_month")
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'United States of America'),
#   Text(1, 0, 'United Kingdom'),
#   Text(2, 0, 'India'),
#   Text(3, 0, 'Canada')])

# %% [markdown]
# We can see a few extreme outliers for India (values over $2500 per month), but it's unclear whether this is good data or not. Maybe these persons attended several bootcamps, which tend to be very expensive. Let's examine these two data points to see if we can find anything relevant.

# %%
# Inspect the extreme outliers for India
india_outliers = four[
    (four['CountryLive'] == 'India') & 
    (four['money_per_month'] >= 2500)]
india_outliers
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1728   24.0               0.0             NaN                NaN          NaN
# 1755   20.0               0.0             NaN                NaN          NaN
# 7989   28.0               0.0             NaN                NaN          NaN
# 8126   22.0               0.0             NaN                NaN          NaN
# 13398  19.0               0.0             NaN                NaN          NaN
# 15587  27.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 1728                 NaN             NaN  between 100,000 and 1 million
# 1755                 NaN             NaN            more than 1 million
# 7989                 NaN             NaN  between 100,000 and 1 million
# 8126                 NaN             NaN            more than 1 million
# 13398                NaN             NaN            more than 1 million
# 15587                NaN             NaN            more than 1 million
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFunFunFunction  \
# 1728                    NaN                   NaN  ...                    NaN
# 1755                    NaN                   NaN  ...                    NaN
# 7989                    1.0                   NaN  ...                    NaN
# 8126                    NaN                   NaN  ...                    NaN
# 13398                   NaN                   NaN  ...                    NaN
# 15587                   NaN                   NaN  ...                    NaN
#
#        YouTubeGoogleDev  YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  \
# 1728                NaN               NaN                 NaN         NaN
# 1755                NaN               1.0                 NaN         1.0
# 7989                NaN               NaN                 NaN         NaN
# 8126                1.0               NaN                 NaN         1.0
# 13398               NaN               NaN                 NaN         NaN
# 15587               1.0               1.0                 NaN         1.0
#
#        YouTubeMozillaHacks  YouTubeOther YouTubeSimplilearn  \
# 1728                   NaN           NaN                NaN
# 1755                   NaN           NaN                NaN
# 7989                   NaN           NaN                NaN
# 8126                   NaN           NaN                NaN
# 13398                  NaN           NaN                NaN
# 15587                  NaN           NaN                NaN
#
#        YouTubeTheNewBoston  money_per_month
# 1728                   NaN      5000.000000
# 1755                   NaN      3333.333333
# 7989                   NaN      5000.000000
# 8126                   1.0      5000.000000
# 13398                  NaN     10000.000000
# 15587                  NaN      4166.666667
#
# [6 rows x 137 columns]

# %% [markdown]
# It seems that neither participant attended a bootcamp. Overall, it's really hard to figure out from the data whether these persons really spent that much money with learning. The actual question of the survey was "Aside from university tuition, about how much money have you spent on learning to code so far (in US dollars)?", so they might have misunderstood and thought university tuition is included. It seems safer to remove these two rows.

# %%
# Remove the outliers for India
four = four.drop(india_outliers.index) # using the row labels
four
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# 15     32.0               0.0             NaN                NaN          NaN
# 16     29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18107  35.0               0.0             NaN                NaN          NaN
# 18111  30.0               0.0             NaN                NaN          NaN
# 18113  24.0               0.0             NaN                NaN          NaN
# 18130  23.0               0.0             NaN                NaN          NaN
# 18156  29.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 1                    NaN             NaN              less than 100,000
# 2                    NaN             NaN            more than 1 million
# 6                    NaN             NaN  between 100,000 and 1 million
# 15                   NaN             NaN              less than 100,000
# 16                   NaN             NaN  between 100,000 and 1 million
# ...                  ...             ...                            ...
# 18107                NaN             2.0              less than 100,000
# 18111                NaN             1.0            more than 1 million
# 18113                NaN             2.0  between 100,000 and 1 million
# 18130                NaN             1.0  between 100,000 and 1 million
# 18156                NaN             1.0  between 100,000 and 1 million
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFunFunFunction  \
# 1                       NaN                   NaN  ...                    NaN
# 2                       NaN                   NaN  ...                    NaN
# 6                       1.0                   NaN  ...                    NaN
# 15                      NaN                   NaN  ...                    NaN
# 16                      NaN                   NaN  ...                    1.0
# ...                     ...                   ...  ...                    ...
# 18107                   NaN                   NaN  ...                    NaN
# 18111                   NaN                   NaN  ...                    1.0
# 18113                   NaN                   NaN  ...                    NaN
# 18130                   NaN                   NaN  ...                    NaN
# 18156                   NaN                   NaN  ...                    NaN
#
#        YouTubeGoogleDev  YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  \
# 1                   NaN               NaN                 NaN         NaN
# 2                   NaN               1.0                 1.0         NaN
# 6                   NaN               NaN                 NaN         NaN
# 15                  NaN               NaN                 NaN         NaN
# 16                  NaN               NaN                 NaN         NaN
# ...                 ...               ...                 ...         ...
# 18107               1.0               NaN                 NaN         NaN
# 18111               NaN               NaN                 NaN         1.0
# 18113               NaN               1.0                 NaN         NaN
# 18130               1.0               NaN                 NaN         1.0
# 18156               NaN               NaN                 NaN         NaN
#
#        YouTubeMozillaHacks  YouTubeOther YouTubeSimplilearn  \
# 1                      NaN           NaN                NaN
# 2                      NaN           NaN                NaN
# 6                      NaN           NaN                NaN
# 15                     NaN           NaN                NaN
# 16                     NaN           NaN                NaN
# ...                    ...           ...                ...
# 18107                  NaN           NaN                NaN
# 18111                  NaN           NaN                NaN
# 18113                  NaN           NaN                NaN
# 18130                  NaN           NaN                NaN
# 18156                  NaN           NaN                NaN
#
#        YouTubeTheNewBoston  money_per_month
# 1                      NaN        13.333333
# 2                      NaN       200.000000
# 6                      NaN         0.000000
# 15                     NaN         0.000000
# 16                     1.0        16.666667
# ...                    ...              ...
# 18107                  NaN       275.000000
# 18111                  NaN       200.000000
# 18113                  NaN         0.000000
# 18130                  NaN         0.000000
# 18156                  NaN      1000.000000
#
# [3907 rows x 137 columns]

# %% [markdown]
# Looking back at the box plot above, we can also see more extreme outliers for the US (values over $6000 per month). Let's examine these participants in more detail.

# %%
usa_outliers = four[
    (four['CountryLive'] == 'United States of America') & 
    (four['money_per_month'] >= 6000)]
usa_outliers
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# 718    26.0               1.0             0.0                0.0
# 1222   32.0               1.0             0.0                0.0
# 3184   34.0               1.0             1.0                0.0
# 3930   31.0               0.0             NaN                NaN
# 6805   46.0               1.0             1.0                1.0
# 7198   32.0               0.0             NaN                NaN
# 7505   26.0               1.0             0.0                1.0
# 9778   33.0               1.0             0.0                1.0
# 16650  29.0               0.0             NaN                NaN
# 16997  27.0               0.0             NaN                NaN
# 17231  50.0               0.0             NaN                NaN
#
#                                  BootcampName  BootcampRecommend  \
# 718    The Coding Boot Camp at UCLA Extension                1.0
# 1222                            The Iron Yard                1.0
# 3184                           We Can Code IT                1.0
# 3930                                      NaN                NaN
# 6805                                 Sabio.la                0.0
# 7198                                      NaN                NaN
# 7505                                   Codeup                0.0
# 9778                             Grand Circus                1.0
# 16650                                     NaN                NaN
# 16997                                     NaN                NaN
# 17231                                     NaN                NaN
#
#        ChildrenNumber                 CityPopulation  CodeEventConferences  \
# 718               NaN            more than 1 million                   1.0
# 1222              NaN  between 100,000 and 1 million                   NaN
# 3184              NaN            more than 1 million                   NaN
# 3930              NaN  between 100,000 and 1 million                   NaN
# 6805              NaN  between 100,000 and 1 million                   NaN
# 7198              NaN            more than 1 million                   1.0
# 7505              NaN            more than 1 million                   NaN
# 9778              NaN  between 100,000 and 1 million                   NaN
# 16650             2.0            more than 1 million                   NaN
# 16997             1.0            more than 1 million                   NaN
# 17231             2.0              less than 100,000                   NaN
#
#        CodeEventDjangoGirls  ...  YouTubeFunFunFunction  YouTubeGoogleDev  \
# 718                     NaN  ...                    NaN               NaN
# 1222                    NaN  ...                    NaN               NaN
# 3184                    NaN  ...                    NaN               NaN
# 3930                    NaN  ...                    1.0               1.0
# 6805                    NaN  ...                    NaN               NaN
# 7198                    NaN  ...                    NaN               1.0
# 7505                    NaN  ...                    NaN               NaN
# 9778                    NaN  ...                    NaN               NaN
# 16650                   NaN  ...                    NaN               NaN
# 16997                   NaN  ...                    NaN               NaN
# 17231                   NaN  ...                    NaN               NaN
#
#        YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  YouTubeMozillaHacks  \
# 718                 NaN                 NaN         NaN                  NaN
# 1222                1.0                 NaN         NaN                  NaN
# 3184                NaN                 NaN         NaN                  NaN
# 3930                1.0                 1.0         1.0                  NaN
# 6805                NaN                 NaN         NaN                  NaN
# 7198                1.0                 1.0         NaN                  NaN
# 7505                NaN                 NaN         1.0                  NaN
# 9778                NaN                 NaN         NaN                  NaN
# 16650               NaN                 NaN         NaN                  NaN
# 16997               NaN                 NaN         NaN                  NaN
# 17231               NaN                 NaN         NaN                  NaN
#
#                      YouTubeOther YouTubeSimplilearn  YouTubeTheNewBoston  \
# 718                           NaN                NaN                  NaN
# 1222                          NaN                NaN                  NaN
# 3184                          NaN                NaN                  NaN
# 3930   various conf presentations                NaN                  NaN
# 6805                          NaN                NaN                  NaN
# 7198                          NaN                NaN                  NaN
# 7505                          NaN                NaN                  NaN
# 9778                          NaN                NaN                  NaN
# 16650                         NaN                NaN                  1.0
# 16997                         NaN                NaN                  NaN
# 17231                         NaN                NaN                  NaN
#
#        money_per_month
# 718        8000.000000
# 1222       6500.000000
# 3184       9000.000000
# 3930      10833.333333
# 6805      15000.000000
# 7198      14000.000000
# 7505       6666.666667
# 9778       8000.000000
# 16650     16666.666667
# 16997     12500.000000
# 17231     15000.000000
#
# [11 rows x 137 columns]

# %%
# Remove the respondents who didn't attendent a bootcamp
no_bootcamp = four[
    (four['CountryLive'] == 'United States of America') & 
    (four['money_per_month'] >= 6000) &
    (four['AttendedBootcamp'] == 0)
]
four=four.drop(no_bootcamp.index)

# Remove the respondents that had been programming for less than 3 months
less_than_3_months = four[
    (four['CountryLive'] == 'United States of America') & 
    (four['money_per_month'] >= 6000) &
    (four['MonthsProgramming'] <= 3)
]

four = four.drop(less_than_3_months.index)
four
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 1      34.0               0.0             NaN                NaN          NaN
# 2      21.0               0.0             NaN                NaN          NaN
# 6      29.0               0.0             NaN                NaN          NaN
# 15     32.0               0.0             NaN                NaN          NaN
# 16     29.0               0.0             NaN                NaN          NaN
# ...     ...               ...             ...                ...          ...
# 18107  35.0               0.0             NaN                NaN          NaN
# 18111  30.0               0.0             NaN                NaN          NaN
# 18113  24.0               0.0             NaN                NaN          NaN
# 18130  23.0               0.0             NaN                NaN          NaN
# 18156  29.0               0.0             NaN                NaN          NaN
#
#        BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 1                    NaN             NaN              less than 100,000
# 2                    NaN             NaN            more than 1 million
# 6                    NaN             NaN  between 100,000 and 1 million
# 15                   NaN             NaN              less than 100,000
# 16                   NaN             NaN  between 100,000 and 1 million
# ...                  ...             ...                            ...
# 18107                NaN             2.0              less than 100,000
# 18111                NaN             1.0            more than 1 million
# 18113                NaN             2.0  between 100,000 and 1 million
# 18130                NaN             1.0  between 100,000 and 1 million
# 18156                NaN             1.0  between 100,000 and 1 million
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFunFunFunction  \
# 1                       NaN                   NaN  ...                    NaN
# 2                       NaN                   NaN  ...                    NaN
# 6                       1.0                   NaN  ...                    NaN
# 15                      NaN                   NaN  ...                    NaN
# 16                      NaN                   NaN  ...                    1.0
# ...                     ...                   ...  ...                    ...
# 18107                   NaN                   NaN  ...                    NaN
# 18111                   NaN                   NaN  ...                    1.0
# 18113                   NaN                   NaN  ...                    NaN
# 18130                   NaN                   NaN  ...                    NaN
# 18156                   NaN                   NaN  ...                    NaN
#
#        YouTubeGoogleDev  YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  \
# 1                   NaN               NaN                 NaN         NaN
# 2                   NaN               1.0                 1.0         NaN
# 6                   NaN               NaN                 NaN         NaN
# 15                  NaN               NaN                 NaN         NaN
# 16                  NaN               NaN                 NaN         NaN
# ...                 ...               ...                 ...         ...
# 18107               1.0               NaN                 NaN         NaN
# 18111               NaN               NaN                 NaN         1.0
# 18113               NaN               1.0                 NaN         NaN
# 18130               1.0               NaN                 NaN         1.0
# 18156               NaN               NaN                 NaN         NaN
#
#        YouTubeMozillaHacks  YouTubeOther YouTubeSimplilearn  \
# 1                      NaN           NaN                NaN
# 2                      NaN           NaN                NaN
# 6                      NaN           NaN                NaN
# 15                     NaN           NaN                NaN
# 16                     NaN           NaN                NaN
# ...                    ...           ...                ...
# 18107                  NaN           NaN                NaN
# 18111                  NaN           NaN                NaN
# 18113                  NaN           NaN                NaN
# 18130                  NaN           NaN                NaN
# 18156                  NaN           NaN                NaN
#
#        YouTubeTheNewBoston  money_per_month
# 1                      NaN        13.333333
# 2                      NaN       200.000000
# 6                      NaN         0.000000
# 15                     NaN         0.000000
# 16                     1.0        16.666667
# ...                    ...              ...
# 18107                  NaN       275.000000
# 18111                  NaN       200.000000
# 18113                  NaN         0.000000
# 18130                  NaN         0.000000
# 18156                  NaN      1000.000000
#
# [3896 rows x 137 columns]

# %% [markdown]
# Looking again at the last box plot above, we can also see an extreme outlier for Canada — a person who spends roughly $5000 per month. Let's examine this person in more depth.

# %%
# Examine the extreme outliers for Canada
canada_outliers = four[
    (four['CountryLive'] == 'Canada') & 
    (four['money_per_month'] > 4500)]

canada_outliers
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 13659  24.0               1.0             0.0                0.0      Bloc.io
#
#        BootcampRecommend  ChildrenNumber       CityPopulation  \
# 13659                1.0             NaN  more than 1 million
#
#        CodeEventConferences  CodeEventDjangoGirls  ...  YouTubeFunFunFunction  \
# 13659                   1.0                   NaN  ...                    NaN
#
#        YouTubeGoogleDev  YouTubeLearnCode  YouTubeLevelUpTuts  YouTubeMIT  \
# 13659               NaN               NaN                 NaN         1.0
#
#        YouTubeMozillaHacks  YouTubeOther YouTubeSimplilearn  \
# 13659                  NaN           NaN                NaN
#
#        YouTubeTheNewBoston  money_per_month
# 13659                  NaN           5000.0
#
# [1 rows x 137 columns]

# %% [markdown]
# Here, the situation is similar to some of the US respondents — this participant had been programming for no more than two months when he completed the survey. He seems to have paid a large sum of money in the beginning to enroll in a bootcamp, and then he probably didn't spend anything for the next couple of months after the survey. We'll take the same approach here as for the US and remove this outlier

# %%
four=four.drop(canada_outliers.index)

# %% [markdown]
# Let's recompute the mean values and generate the final box plots.

# %%
four.groupby("CountryLive")["money_per_month"].mean()
# Out:
# CountryLive
# Canada                       93.065400
# India                        65.758763
# United Kingdom               45.534443
# United States of America    142.654608
# Name: money_per_month, dtype: float64

# %%
sns.boxplot(data=four,x="CountryLive",y="money_per_month")
# Out:
# <Axes: xlabel='CountryLive', ylabel='money_per_month'>

# %% [markdown]
# ## 5.Choosing the Two Best Markets

# %% [markdown]
# * Obviously, one country we should advertise in is the US. Lots of new coders live there and they are willing to pay a good amount of money each month (roughly $143).
#
# * The data suggests strongly that we shouldn't advertise in the UK, but let's take a second look at India before deciding to choose Canada as our second best choice:
#
#     * 59 doesnot seem like expensive sum for people in India, since they spend 66 for month on average
#     * We have almost twice as more potential customers in India than we have in Canada

# %%
# Frequency table for the 'CountryLive' column
four['CountryLive'].value_counts(normalize = True) * 100
# Out:
# CountryLive
# United States of America    74.967908
# India                       11.732991
# United Kingdom               7.163030
# Canada                       6.136072
# Name: proportion, dtype: float64

# %% [markdown]
# So it's not crystal clear what to choose between Canada and India. Although it seems more tempting to choose Canada, there are good chances that India might actually be a better choice because of the large number of potential customers.

# %% [markdown]
# ## 6.Conclusion

# %% [markdown]
# In this project, we analyzed survey data from new coders to find the best two markets to advertise in. The only solid conclusion we reached is that the US would be a good market to advertise in.
#
# For the second best market, it wasn't clear-cut what to choose between India and Canada. We decided to send the results to the marketing team so they can use their domain knowledge to take the best decision.
