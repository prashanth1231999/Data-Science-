# %% [markdown]
# Data & Python Notebook that corresponds to my lego analysis YouTube tutorial: [https://youtu.be/BzQDi4D0B_M]

# %%
# Making a map using the folium module
import folium
phone_map = folium.Map()

# Top three smart phone companies by market share in 2016
companies = [
    {'loc': [13.7527,  79.7067], 'label': 'Datamind: ...%'},]

# Adding markers to the map
for company in companies:
    marker = folium.Marker(location=company['loc'], popup=company['label'])
    marker.add_to(phone_map)

# The last object in the cell always gets shown in the notebook
phone_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4fdb5cd1b90ed79d4f253d56430effbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4fdb5cd1b90ed79d4f253d56430effbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4fdb5cd1b90ed79d4f253d56430effbc = L.map(
#                 &quot;map_4fdb5cd1b90ed79d4f253d56430effbc&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3164a1e0109df06548277e0c6d10c377 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4fdb5cd1b90ed79d4f253d56430effbc);
#
#
#             var marker_b55685b47d5937c886ced865b432a36b = L.marker(
#                 [13.7527, 79.7067],
#                 {}
#             ).addTo(map_4fdb5cd1b90ed79d4f253d56430effbc);
#
#
#         var popup_f9a3467f7398b9ca4994b305242e5702 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16e71cfcd9e2ad5915fa4344b1e4b361 = $(`&lt;div id=&quot;html_16e71cfcd9e2ad5915fa4344b1e4b361&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Datamind: ...%&lt;/div&gt;`)[0];
#                 popup_f9a3467f7398b9ca4994b305242e5702.setContent(html_16e71cfcd9e2ad5915fa4344b1e4b361);
#
#
#
#         marker_b55685b47d5937c886ced865b432a36b.bindPopup(popup_f9a3467f7398b9ca4994b305242e5702)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv("lego_sets.csv")

# %%
df1
# Out:
#       set_num                        name  year  num_parts    theme_name  \
# 0        00-1             Weetabix Castle  1970      471.0        Castle
# 1      0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2      0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3      0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4      0013-1          Space Mini-Figures  1979       12.0  Supplemental
# ...       ...                         ...   ...        ...           ...
# 11981     NaN                         NaN  2014        NaN           NaN
# 11982     NaN                         NaN  2006        NaN           NaN
# 11983     NaN                         NaN  2017        NaN           NaN
# 11984     NaN                         NaN  2017        8.0           NaN
# 11985     NaN                         NaN  2003        NaN           NaN
#
#        parent_theme
# 0          Legoland
# 1              Town
# 2            Castle
# 3             Space
# 4             Space
# ...             ...
# 11981     Minecraft
# 11982  Super Heroes
# 11983     Minecraft
# 11984  Super Heroes
# 11985  Harry Potter
#
# [11986 rows x 6 columns]

# %%
df1.isnull().sum()
# Out:
# set_num          153
# name             153
# year               0
# num_parts       5060
# theme_name       153
# parent_theme       0
# dtype: int64

# %%
df1.dropna(subset=["set_num","name","theme_name"])
# Out:
#              set_num                                               name  year  \
# 0               00-1                                    Weetabix Castle  1970
# 1             0011-2                                  Town Mini-Figures  1978
# 2             0011-3                         Castle 2 for 1 Bonus Offer  1987
# 3             0012-1                                 Space Mini-Figures  1979
# 4             0013-1                                 Space Mini-Figures  1979
# ...              ...                                                ...   ...
# 11828    Wauwatosa-1  LEGO Store Grand Opening Exclusive Set, Mayfai...  2012
# 11829   WHITEHOUSE-1                                  Micro White House  2015
# 11830    Wiesbaden-1  LEGO Store Grand Opening Exclusive Set, Wiesba...  2010
# 11831  WishingWell-1                     Wishing Well [Toys R Us Promo]  2013
# 11832        wwgp1-1                Wild West Limited Edition Gift Pack  1996
#
#        num_parts        theme_name      parent_theme
# 0          471.0            Castle          Legoland
# 1            NaN      Supplemental              Town
# 2            NaN      Lion Knights            Castle
# 3           12.0      Supplemental             Space
# 4           12.0      Supplemental             Space
# ...          ...               ...               ...
# 11828       15.0  LEGO Brand Store  LEGO Brand Store
# 11829        NaN       Promotional       Promotional
# 11830      146.0  LEGO Brand Store  LEGO Brand Store
# 11831        NaN           Friends           Friends
# 11832        NaN           Cowboys           Western
#
# [11833 rows x 6 columns]

# %%
df1["parent_theme"].unique()
# Out:
# array(['Legoland', 'Town', 'Castle', 'Space', 'Classic', 'Gear',
#        'Universal Building Set', 'Train', 'Bulk Bricks', 'Star Wars',
#        'Hobby Sets', 'Bionicle', 'Sculptures', 'Discovery', 'Pirates',
#        'Seasonal', 'Super Heroes', 'Clikits', 'Sports', 'Harry Potter',
#        'Model Team', 'Other', 'Modular Buildings', 'Factory',
#        'Service Packs', 'Monster Fighters',
#        'The Hobbit and Lord of the Rings', 'Creator', 'Adventurers',
#        'Mindstorms', 'Technic', 'Educational and Dacta', 'Duplo',
#        'Disney Princess', 'Juniors', 'Friends', 'Aquazone', 'Ninja',
#        'Minitalia', 'Books', 'Ninjago', 'Hero Factory', 'Racers',
#        'Fabuland', 'Rock Raiders', 'Studios', 'Alpha Team', '4 Juniors',
#        'Building Set with People', 'Boat', 'Value Packs', 'Freestyle',
#        'Time Cruisers', 'Indiana Jones', 'Master Building Academy',
#        'FIRST LEGO League', 'Atlantis', 'Prince of Persia',
#        'Architecture', 'LEGO Ideas and CUUSOO', 'Minecraft', 'Fusion',
#        'Homemaker', 'Elves', 'Belville', 'Nexo Knights', 'Western',
#        'Promotional', 'Toy Story', "Pharaoh's Quest", 'Cars',
#        'Pirates of the Caribbean', 'Legends of Chima', 'The Lone Ranger',
#        'Teenage Mutant Ninja Turtles', 'The LEGO Movie', 'Jurassic World',
#        'Scooby-Doo', 'Designer Sets', 'LEGO Brand Store',
#        'Island Xtreme Stunts', 'Znap', "Disney's Mickey Mouse",
#        'Spybiotics', 'SpongeBob SquarePants', 'Avatar', 'Exo-Force',
#        'Legoland Parks', 'Inventor', 'Brickheadz', 'Mixels', 'X-Pod',
#        'Power Miners', 'Collectible Minifigures', 'Speed Champions',
#        'Agents', 'LEGO Exclusive', 'Universe', 'Dino', 'Dinosaurs',
#        'Vikings', 'Disney', 'Dimensions', 'Dino 2010', 'Dino Attack',
#        'Angry Birds', 'Ghostbusters', 'Power Functions', 'Ben 10'],
#       dtype=object)

# %%
df2=pd.read_csv("parent_themes.csv")

# %%
df2
# Out:
#       id          name  is_licensed
# 0      1       Technic        False
# 1     22       Creator        False
# 2     50          Town        False
# 3    112        Racers        False
# 4    126         Space        False
# ..   ...           ...          ...
# 106  605  Nexo Knights        False
# 107  606   Angry Birds         True
# 108  607  Ghostbusters         True
# 109  608        Disney         True
# 110  610    Brickheadz        False
#
# [111 rows x 3 columns]

# %%
def func(x):
    return df2[df2["name"]==x]["is_licensed"][0]

# %%
func("Technic")
# Out:
# False

# %%
df2[df2["name"]=="Technic"]["is_licensed"][0]
# Out:
# False

# %%
df1["is_licensed"]=df1["parent_theme"].map(func)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df1["is_licensed"]=df1["parent_theme"].map(func)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\series.py:4539, in Series.map(self, arg, na_action)
#    4460 def map(
#    4461     self,
#    4462     arg: Callable | Mapping | Series,
#    4463     na_action: Literal["ignore"] | None = None,
#    4464 ) -> Series:
#    4465     """
#    4466     Map values of Series according to an input mapping or function.
#    4467
#    (...)
#    4537     dtype: object
#    4538     """
# -> 4539     new_values = self._map_values(arg, na_action=na_action)
#    4540     return self._constructor(new_values, index=self.index).__finalize__(
#    4541         self, method="map"
#    4542     )
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\base.py:890, in IndexOpsMixin._map_values(self, mapper, na_action)
#     887         raise ValueError(msg)
#     889 # mapper is a function
# --> 890 new_values = map_f(values, mapper)
#     892 return new_values
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[25], line 2, in func(x)
#       1 def func(x):
# ----> 2     return df2[df2["name"]==x]["is_licensed"][0]
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0
